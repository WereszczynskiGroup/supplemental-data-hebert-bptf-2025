# %%
import matplotlib.pyplot as plt
import numpy as np

a = np.loadtxt("nucleosome_h3k4me3sasa1.dat", usecols=(0), unpack=True, comments=('#','@','&'))
x1= np.loadtxt("nucleosome_h3k4me3sasa1.dat", usecols=(1), unpack=True, comments=('#','@','&'))
x2 = np.loadtxt("nucleosome_h3k4me3sasa2.dat", usecols=(1), unpack=True, comments=('#','@','&'))
x3 = np.loadtxt("nucleosome_h3k4me3sasa3.dat", usecols=(1), unpack=True, comments=('#','@','&'))
x4 = np.loadtxt("nucleosome_h3k4me3sasa4.dat", usecols=(1), unpack=True, comments=('#','@','&'))
x5 = np.loadtxt("nucleosome_h3k4me3sasa5.dat", usecols=(1), unpack=True, comments=('#','@','&'))
xx1 = np.loadtxt("nucleosome_h3sasa1.dat", usecols=(1), unpack=True, comments=('#','@','&'))
xx2 = np.loadtxt("nucleosome_h3sasa2.dat", usecols=(1), unpack=True, comments=('#','@','&'))
xx3 = np.loadtxt("nucleosome_h3sasa3.dat", usecols=(1), unpack=True, comments=('#','@','&'))
xx4 = np.loadtxt("nucleosome_h3sasa4.dat", usecols=(1), unpack=True, comments=('#','@','&'))
xx5 = np.loadtxt("nucleosome_h3sasa5.dat", usecols=(1), unpack=True, comments=('#','@','&'))

y1 = np.loadtxt("phd_ncp_h3k4me3sasa1.dat", usecols=(1), unpack=True, comments=('#','@','&'))
y2 = np.loadtxt("phd_ncp_h3k4me3sasa2.dat", usecols=(1), unpack=True, comments=('#','@','&'))
y3 = np.loadtxt("phd_ncp_h3k4me3sasa3.dat", usecols=(1), unpack=True, comments=('#','@','&'))
y4 = np.loadtxt("phd_ncp_h3k4me3sasa4.dat", usecols=(1), unpack=True, comments=('#','@','&'))
y5 = np.loadtxt("phd_ncp_h3k4me3sasa5.dat", usecols=(1), unpack=True, comments=('#','@','&'))
yy1 = np.loadtxt("phd_ncp_h3sasa1.dat", usecols=(1), unpack=True, comments=('#','@','&'))
yy2 = np.loadtxt("phd_ncp_h3sasa2.dat", usecols=(1), unpack=True, comments=('#','@','&'))
yy3 = np.loadtxt("phd_ncp_h3sasa3.dat", usecols=(1), unpack=True, comments=('#','@','&'))
yy4 = np.loadtxt("phd_ncp_h3sasa4.dat", usecols=(1), unpack=True, comments=('#','@','&'))
yy5 = np.loadtxt("phd_ncp_h3sasa5.dat", usecols=(1), unpack=True, comments=('#','@','&'))

z1 = np.loadtxt("bptf_ncp_h3k4me3sasa1.dat", usecols=(1), unpack=True, comments=('#','@','&'))
z2 = np.loadtxt("bptf_ncp_h3k4me3sasa2.dat", usecols=(1), unpack=True, comments=('#','@','&'))
z3 = np.loadtxt("bptf_ncp_h3k4me3sasa3.dat", usecols=(1), unpack=True, comments=('#','@','&'))
z4 = np.loadtxt("bptf_ncp_h3k4me3sasa4.dat", usecols=(1), unpack=True, comments=('#','@','&'))
z5 = np.loadtxt("bptf_ncp_h3k4me3sasa5.dat", usecols=(1), unpack=True, comments=('#','@','&'))
zz1 = np.loadtxt("bptf_ncp_h3sasa1.dat", usecols=(1), unpack=True, comments=('#','@','&'))
zz2 = np.loadtxt("bptf_ncp_h3sasa2.dat", usecols=(1), unpack=True, comments=('#','@','&'))
zz3 = np.loadtxt("bptf_ncp_h3sasa3.dat", usecols=(1), unpack=True, comments=('#','@','&'))
zz4 = np.loadtxt("bptf_ncp_h3sasa4.dat", usecols=(1), unpack=True, comments=('#','@','&'))
zz5 = np.loadtxt("bptf_ncp_h3sasa5.dat", usecols=(1), unpack=True, comments=('#','@','&'))
#d0 = np.concatenate((d1[-7000:],d2[-7000:],d3[-7000:],d4[-7000:],d5[-7000:]))
#d = np.concatenate((d1,d2,d3,d4,d5))

# %%
fig, axs = plt.subplots(5,3, sharex=True, sharey=True)
fig.suptitle('H3k4me3 Tail SASA vs. Time', fontweight='bold', fontsize=12)
axs[0,0].plot(a/10, x1, color='black')
axs[0,0].set_title('NCP')
axs[0,0].set_xlim(0,1000)
axs[0,0].set_ylim(1500,4500)
axs[0,0].set_yticks(np.arange(1500,6000,1500))
axs[1,0].plot(a/10, x2, color='black')
axs[2,0].plot(a/10, x3, color='black')
axs[2,0].set_ylabel('Solvent Accessible Surface Area ($\AA^2$)', fontsize=12)
axs[3,0].plot(a/10, x4, color='black')
axs[4,0].plot(a/10, x5, color='black')
axs[4,0].set_xticks(np.arange(0,1250,250))
axs[4,0].set_xticklabels(('0','','500','','1000'))

xmin, xmax = axs[0,1].get_xlim()
text_y = axs[0,1].get_ylim()[1] * 1.50
axs[0,1].plot(a/10, y1, color='black')
axs[0,1].set_title('PHD + NCP')
axs[1,1].plot(a/10, y2, color='black')
axs[2,1].plot(a/10, y3, color='black')
axs[3,1].plot(a/10, y4, color='black')
axs[4,1].plot(a/10, y5, color='black')
axs[4,1].set_xlabel('Time (ns)')

axs[0,2].plot(a/10, z1, color='black')
axs[0,2].set_title('BPTF + NCP')
ax0=axs[0,2].twinx()
ax0.set_yticks([])
ax0.set_ylabel('Run 1', rotation=315,  labelpad=25)
axs[1,2].plot(a/10, z2, color='black')
ax1=axs[1,2].twinx()
ax1.set_yticks([])
ax1.set_ylabel('Run 2', rotation=315,  labelpad=25)
axs[2,2].plot(a/10, z3, color='black')
ax2=axs[2,2].twinx()
ax2.set_yticks([])
ax2.set_ylabel('Run 3', rotation=315,  labelpad=25)
axs[3,2].plot(a/10, z4, color='black')
ax3=axs[3,2].twinx()
ax3.set_yticks([])
ax3.set_ylabel('Run 4', rotation=315,  labelpad=25)
axs[4,2].plot(a/10, z5, color='black')
ax4=axs[4,2].twinx()
ax4.set_yticks([])
ax4.set_ylabel('Run 5', rotation=315,  labelpad=25)
plt.tight_layout()
plt.savefig('h3k4me3sasa_time.pdf')

plt.show()

# %%
fig, axs = plt.subplots(5,3, sharex=True, sharey=True)
fig.suptitle('Unmodified H3 Tail SASA vs. Time', fontweight='bold', fontsize=12)
axs[0,0].plot(a/10, xx1, color='black')
axs[0,0].set_title('NCP')
axs[0,0].set_xlim(0,1000)
axs[0,0].set_ylim(1500,4500)
axs[0,0].set_yticks(np.arange(1500,6000,1500))
axs[1,0].plot(a/10, xx2, color='black')
axs[2,0].plot(a/10, xx3, color='black')
axs[2,0].set_ylabel('Solvent Accessible Surface Area ($\AA^2$)', fontsize=12)
axs[3,0].plot(a/10, xx4, color='black')
axs[4,0].plot(a/10, xx5, color='black')
axs[4,0].set_xticks(np.arange(0,1250,250))
axs[4,0].set_xticklabels(('0','','500','','1000'))

xmin, xmax = axs[0,1].get_xlim()
text_y = axs[0,1].get_ylim()[1] * 1.50
axs[0,1].plot(a/10, yy1, color='black')
axs[0,1].set_title('PHD + NCP')
axs[1,1].plot(a/10, yy2, color='black')
axs[2,1].plot(a/10, yy3, color='black')
axs[3,1].plot(a/10, yy4, color='black')
axs[4,1].plot(a/10, yy5, color='black')
axs[4,1].set_xlabel('Time (ns)')

axs[0,2].plot(a/10, zz1, color='black')
axs[0,2].set_title('BPTF + NCP')
ax0=axs[0,2].twinx()
ax0.set_yticks([])
ax0.set_ylabel('Run 1', rotation=315,  labelpad=25)
axs[1,2].plot(a/10, zz2, color='black')
ax1=axs[1,2].twinx()
ax1.set_yticks([])
ax1.set_ylabel('Run 2', rotation=315,  labelpad=25)
axs[2,2].plot(a/10, zz3, color='black')
ax2=axs[2,2].twinx()
ax2.set_yticks([])
ax2.set_ylabel('Run 3', rotation=315,  labelpad=25)
axs[3,2].plot(a/10, zz4, color='black')
ax3=axs[3,2].twinx()
ax3.set_yticks([])
ax3.set_ylabel('Run 4', rotation=315,  labelpad=25)
axs[4,2].plot(a/10, zz5, color='black')
ax4=axs[4,2].twinx()
ax4.set_yticks([])
ax4.set_ylabel('Run 5', rotation=315,  labelpad=25)
plt.tight_layout()
plt.savefig('h3sasa_time.pdf')

plt.show()
