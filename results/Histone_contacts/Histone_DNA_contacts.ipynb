# %%
import statistics as stat
import numpy as np
import matplotlib.pyplot as plt

font = {'family': 'sans-serif',
        'color':  'black',
        'weight': 'bold',
        'size': 12,
        }

# Full Histone Contacts
mh2a1 = np.loadtxt('./Hist_contacts/nucleosomeH2a_1.dat', usecols=(1), unpack=True, comments=('#'))
mh2a2 = np.loadtxt('./Hist_contacts/nucleosomeH2a_2.dat', usecols=(1), unpack=True, comments=('#'))
mh2a3 = np.loadtxt('./Hist_contacts/nucleosomeH2a_3.dat', usecols=(1), unpack=True, comments=('#'))
mh2a4 = np.loadtxt('./Hist_contacts/nucleosomeH2a_4.dat', usecols=(1), unpack=True, comments=('#'))
mh2a5 = np.loadtxt('./Hist_contacts/nucleosomeH2a_5.dat', usecols=(1), unpack=True, comments=('#'))
mh2b1 = np.loadtxt('./Hist_contacts/nucleosomeH2b_1.dat', usecols=(1), unpack=True, comments=('#'))
mh2b2 = np.loadtxt('./Hist_contacts/nucleosomeH2b_2.dat', usecols=(1), unpack=True, comments=('#'))
mh2b3 = np.loadtxt('./Hist_contacts/nucleosomeH2b_3.dat', usecols=(1), unpack=True, comments=('#'))
mh2b4 = np.loadtxt('./Hist_contacts/nucleosomeH2b_4.dat', usecols=(1), unpack=True, comments=('#'))
mh2b5 = np.loadtxt('./Hist_contacts/nucleosomeH2b_5.dat', usecols=(1), unpack=True, comments=('#'))
mh31 = np.loadtxt('./Hist_contacts/nucleosomeH3_1.dat', usecols=(1), unpack=True, comments=('#'))
mh32 = np.loadtxt('./Hist_contacts/nucleosomeH3_2.dat', usecols=(1), unpack=True, comments=('#'))
mh33 = np.loadtxt('./Hist_contacts/nucleosomeH3_3.dat', usecols=(1), unpack=True, comments=('#'))
mh34 = np.loadtxt('./Hist_contacts/nucleosomeH3_4.dat', usecols=(1), unpack=True, comments=('#'))
mh35 = np.loadtxt('./Hist_contacts/nucleosomeH3_5.dat', usecols=(1), unpack=True, comments=('#'))
mh41 = np.loadtxt('./Hist_contacts/nucleosomeH4_1.dat', usecols=(1), unpack=True, comments=('#'))
mh42 = np.loadtxt('./Hist_contacts/nucleosomeH4_2.dat', usecols=(1), unpack=True, comments=('#'))
mh43 = np.loadtxt('./Hist_contacts/nucleosomeH4_3.dat', usecols=(1), unpack=True, comments=('#'))
mh44 = np.loadtxt('./Hist_contacts/nucleosomeH4_4.dat', usecols=(1), unpack=True, comments=('#'))
mh45 = np.loadtxt('./Hist_contacts/nucleosomeH4_5.dat', usecols=(1), unpack=True, comments=('#'))
mh2a=np.concatenate((mh2a1[-700:],mh2a2[-700:],mh2a3[-700:],mh2a4[-700:],mh2a5[-700:]))
mh2b=np.concatenate((mh2b1[-700:],mh2b2[-700:],mh2b3[-700:],mh2b4[-700:],mh2b5[-700:]))
mh3=np.concatenate((mh31[-700:],mh32[-700:],mh33[-700:],mh34[-700:],mh35[-700:]))
mh4=np.concatenate((mh41[-700:],mh42[-700:],mh43[-700:],mh44[-700:],mh45[-700:]))

eh2a1 = np.loadtxt('./Hist_contacts/phd_ncpH2a_1.dat', usecols=(1), unpack=True, comments=('#'))
eh2a2 = np.loadtxt('./Hist_contacts/phd_ncpH2a_2.dat', usecols=(1), unpack=True, comments=('#'))
eh2a3 = np.loadtxt('./Hist_contacts/phd_ncpH2a_3.dat', usecols=(1), unpack=True, comments=('#'))
eh2a4 = np.loadtxt('./Hist_contacts/phd_ncpH2a_4.dat', usecols=(1), unpack=True, comments=('#'))
eh2a5 = np.loadtxt('./Hist_contacts/phd_ncpH2a_5.dat', usecols=(1), unpack=True, comments=('#'))
eh2b1 = np.loadtxt('./Hist_contacts/phd_ncpH2b_1.dat', usecols=(1), unpack=True, comments=('#'))
eh2b2 = np.loadtxt('./Hist_contacts/phd_ncpH2b_2.dat', usecols=(1), unpack=True, comments=('#'))
eh2b3 = np.loadtxt('./Hist_contacts/phd_ncpH2b_3.dat', usecols=(1), unpack=True, comments=('#'))
eh2b4 = np.loadtxt('./Hist_contacts/phd_ncpH2b_4.dat', usecols=(1), unpack=True, comments=('#'))
eh2b5 = np.loadtxt('./Hist_contacts/phd_ncpH2b_5.dat', usecols=(1), unpack=True, comments=('#'))
eh31 = np.loadtxt('./Hist_contacts/phd_ncpH3_1.dat', usecols=(1), unpack=True, comments=('#'))
eh32 = np.loadtxt('./Hist_contacts/phd_ncpH3_2.dat', usecols=(1), unpack=True, comments=('#'))
eh33 = np.loadtxt('./Hist_contacts/phd_ncpH3_3.dat', usecols=(1), unpack=True, comments=('#'))
eh34 = np.loadtxt('./Hist_contacts/phd_ncpH3_4.dat', usecols=(1), unpack=True, comments=('#'))
eh35 = np.loadtxt('./Hist_contacts/phd_ncpH3_5.dat', usecols=(1), unpack=True, comments=('#'))
eh41 = np.loadtxt('./Hist_contacts/phd_ncpH4_1.dat', usecols=(1), unpack=True, comments=('#'))
eh42 = np.loadtxt('./Hist_contacts/phd_ncpH4_2.dat', usecols=(1), unpack=True, comments=('#'))
eh43 = np.loadtxt('./Hist_contacts/phd_ncpH4_3.dat', usecols=(1), unpack=True, comments=('#'))
eh44 = np.loadtxt('./Hist_contacts/phd_ncpH4_4.dat', usecols=(1), unpack=True, comments=('#'))
eh45 = np.loadtxt('./Hist_contacts/phd_ncpH4_5.dat', usecols=(1), unpack=True, comments=('#'))
eh2a=np.concatenate((eh2a1[-700:],eh2a2[-700:],eh2a3[-700:],eh2a4[-700:],eh2a5[-700:]))
eh2b=np.concatenate((eh2b1[-700:],eh2b2[-700:],eh2b3[-700:],eh2b4[-700:],eh2b5[-700:]))
eh3=np.concatenate((eh31[-700:],eh32[-700:],eh33[-700:],eh34[-700:],eh35[-700:]))
eh4=np.concatenate((eh41[-700:],eh42[-700:],eh43[-700:],eh44[-700:],eh45[-700:]))

Eh2a1 = np.loadtxt('./Hist_contacts/bptf_ncpH2a_1.dat', usecols=(1), unpack=True, comments=('#'))
Eh2a2 = np.loadtxt('./Hist_contacts/bptf_ncpH2a_2.dat', usecols=(1), unpack=True, comments=('#'))
Eh2a3 = np.loadtxt('./Hist_contacts/bptf_ncpH2a_3.dat', usecols=(1), unpack=True, comments=('#'))
Eh2a4 = np.loadtxt('./Hist_contacts/bptf_ncpH2a_4.dat', usecols=(1), unpack=True, comments=('#'))
Eh2a5 = np.loadtxt('./Hist_contacts/bptf_ncpH2a_5.dat', usecols=(1), unpack=True, comments=('#'))
Eh2b1 = np.loadtxt('./Hist_contacts/bptf_ncpH2b_1.dat', usecols=(1), unpack=True, comments=('#'))
Eh2b2 = np.loadtxt('./Hist_contacts/bptf_ncpH2b_2.dat', usecols=(1), unpack=True, comments=('#'))
Eh2b3 = np.loadtxt('./Hist_contacts/bptf_ncpH2b_3.dat', usecols=(1), unpack=True, comments=('#'))
Eh2b4 = np.loadtxt('./Hist_contacts/bptf_ncpH2b_4.dat', usecols=(1), unpack=True, comments=('#'))
Eh2b5 = np.loadtxt('./Hist_contacts/bptf_ncpH2b_5.dat', usecols=(1), unpack=True, comments=('#'))
Eh31 = np.loadtxt('./Hist_contacts/bptf_ncpH3_1.dat', usecols=(1), unpack=True, comments=('#'))
Eh32 = np.loadtxt('./Hist_contacts/bptf_ncpH3_2.dat', usecols=(1), unpack=True, comments=('#'))
Eh33 = np.loadtxt('./Hist_contacts/bptf_ncpH3_3.dat', usecols=(1), unpack=True, comments=('#'))
Eh34 = np.loadtxt('./Hist_contacts/bptf_ncpH3_4.dat', usecols=(1), unpack=True, comments=('#'))
Eh35 = np.loadtxt('./Hist_contacts/bptf_ncpH3_5.dat', usecols=(1), unpack=True, comments=('#'))
Eh41 = np.loadtxt('./Hist_contacts/bptf_ncpH4_1.dat', usecols=(1), unpack=True, comments=('#'))
Eh42 = np.loadtxt('./Hist_contacts/bptf_ncpH4_2.dat', usecols=(1), unpack=True, comments=('#'))
Eh43 = np.loadtxt('./Hist_contacts/bptf_ncpH4_3.dat', usecols=(1), unpack=True, comments=('#'))
Eh44 = np.loadtxt('./Hist_contacts/bptf_ncpH4_4.dat', usecols=(1), unpack=True, comments=('#'))
Eh45 = np.loadtxt('./Hist_contacts/bptf_ncpH4_5.dat', usecols=(1), unpack=True, comments=('#'))
Eh2a=np.concatenate((Eh2a1[-700:],Eh2a2[-700:],Eh2a3[-700:],Eh2a4[-700:],Eh2a5[-700:]))
Eh2b=np.concatenate((Eh2b1[-700:],Eh2b2[-700:],Eh2b3[-700:],Eh2b4[-700:],Eh2b5[-700:]))
Eh3=np.concatenate((Eh31[-700:],Eh32[-700:],Eh33[-700:],Eh34[-700:],Eh35[-700:]))
Eh4=np.concatenate((Eh41[-700:],Eh42[-700:],Eh43[-700:],Eh44[-700:],Eh45[-700:]))


# Histone Tail Contacts
mth2a1 = np.loadtxt('./Hist_contacts/nucleosomeH2atails_1.dat', usecols=(1), unpack=True, comments=('#'))
mth2a2 = np.loadtxt('./Hist_contacts/nucleosomeH2atails_2.dat', usecols=(1), unpack=True, comments=('#'))
mth2a3 = np.loadtxt('./Hist_contacts/nucleosomeH2atails_3.dat', usecols=(1), unpack=True, comments=('#'))
mth2a4 = np.loadtxt('./Hist_contacts/nucleosomeH2atails_4.dat', usecols=(1), unpack=True, comments=('#'))
mth2a5 = np.loadtxt('./Hist_contacts/nucleosomeH2atails_5.dat', usecols=(1), unpack=True, comments=('#'))
mth2b1 = np.loadtxt('./Hist_contacts/nucleosomeH2btails_1.dat', usecols=(1), unpack=True, comments=('#'))
mth2b2 = np.loadtxt('./Hist_contacts/nucleosomeH2btails_2.dat', usecols=(1), unpack=True, comments=('#'))
mth2b3 = np.loadtxt('./Hist_contacts/nucleosomeH2btails_3.dat', usecols=(1), unpack=True, comments=('#'))
mth2b4 = np.loadtxt('./Hist_contacts/nucleosomeH2btails_4.dat', usecols=(1), unpack=True, comments=('#'))
mth2b5 = np.loadtxt('./Hist_contacts/nucleosomeH2btails_5.dat', usecols=(1), unpack=True, comments=('#'))
mth31 = np.loadtxt('./Hist_contacts/nucleosomeH3tails_1.dat', usecols=(1), unpack=True, comments=('#'))
mth32 = np.loadtxt('./Hist_contacts/nucleosomeH3tails_2.dat', usecols=(1), unpack=True, comments=('#'))
mth33 = np.loadtxt('./Hist_contacts/nucleosomeH3tails_3.dat', usecols=(1), unpack=True, comments=('#'))
mth34 = np.loadtxt('./Hist_contacts/nucleosomeH3tails_4.dat', usecols=(1), unpack=True, comments=('#'))
mth35 = np.loadtxt('./Hist_contacts/nucleosomeH3tails_5.dat', usecols=(1), unpack=True, comments=('#'))
mth41 = np.loadtxt('./Hist_contacts/nucleosomeH4tails_1.dat', usecols=(1), unpack=True, comments=('#'))
mth42 = np.loadtxt('./Hist_contacts/nucleosomeH4tails_2.dat', usecols=(1), unpack=True, comments=('#'))
mth43 = np.loadtxt('./Hist_contacts/nucleosomeH4tails_3.dat', usecols=(1), unpack=True, comments=('#'))
mth44 = np.loadtxt('./Hist_contacts/nucleosomeH4tails_4.dat', usecols=(1), unpack=True, comments=('#'))
mth45 = np.loadtxt('./Hist_contacts/nucleosomeH4tails_5.dat', usecols=(1), unpack=True, comments=('#'))
mth2a=np.concatenate((mth2a1[-700:],mth2a2[-700:],mth2a3[-700:],mth2a4[-700:],mth2a5[-700:]))
mth2b=np.concatenate((mth2b1[-700:],mth2b2[-700:],mth2b3[-700:],mth2b4[-700:],mth2b5[-700:]))
mth3=np.concatenate((mth31[-700:],mth32[-700:],mth33[-700:],mth34[-700:],mth35[-700:]))
mth4=np.concatenate((mth41[-700:],mth42[-700:],mth43[-700:],mth44[-700:],mth45[-700:]))

eth2a1 = np.loadtxt('./Hist_contacts/phd_ncpH2atails_1.dat', usecols=(1), unpack=True, comments=('#'))
eth2a2 = np.loadtxt('./Hist_contacts/phd_ncpH2atails_2.dat', usecols=(1), unpack=True, comments=('#'))
eth2a3 = np.loadtxt('./Hist_contacts/phd_ncpH2atails_3.dat', usecols=(1), unpack=True, comments=('#'))
eth2a4 = np.loadtxt('./Hist_contacts/phd_ncpH2atails_4.dat', usecols=(1), unpack=True, comments=('#'))
eth2a5 = np.loadtxt('./Hist_contacts/phd_ncpH2atails_5.dat', usecols=(1), unpack=True, comments=('#'))
eth2b1 = np.loadtxt('./Hist_contacts/phd_ncpH2btails_1.dat', usecols=(1), unpack=True, comments=('#'))
eth2b2 = np.loadtxt('./Hist_contacts/phd_ncpH2btails_2.dat', usecols=(1), unpack=True, comments=('#'))
eth2b3 = np.loadtxt('./Hist_contacts/phd_ncpH2btails_3.dat', usecols=(1), unpack=True, comments=('#'))
eth2b4 = np.loadtxt('./Hist_contacts/phd_ncpH2btails_4.dat', usecols=(1), unpack=True, comments=('#'))
eth2b5 = np.loadtxt('./Hist_contacts/phd_ncpH2btails_5.dat', usecols=(1), unpack=True, comments=('#'))
eth31 = np.loadtxt('./Hist_contacts/phd_ncpH3tails_1.dat', usecols=(1), unpack=True, comments=('#'))
eth32 = np.loadtxt('./Hist_contacts/phd_ncpH3tails_2.dat', usecols=(1), unpack=True, comments=('#'))
eth33 = np.loadtxt('./Hist_contacts/phd_ncpH3tails_3.dat', usecols=(1), unpack=True, comments=('#'))
eth34 = np.loadtxt('./Hist_contacts/phd_ncpH3tails_4.dat', usecols=(1), unpack=True, comments=('#'))
eth35 = np.loadtxt('./Hist_contacts/phd_ncpH3tails_5.dat', usecols=(1), unpack=True, comments=('#'))
eth41 = np.loadtxt('./Hist_contacts/phd_ncpH4tails_1.dat', usecols=(1), unpack=True, comments=('#'))
eth42 = np.loadtxt('./Hist_contacts/phd_ncpH4tails_2.dat', usecols=(1), unpack=True, comments=('#'))
eth43 = np.loadtxt('./Hist_contacts/phd_ncpH4tails_3.dat', usecols=(1), unpack=True, comments=('#'))
eth44 = np.loadtxt('./Hist_contacts/phd_ncpH4tails_4.dat', usecols=(1), unpack=True, comments=('#'))
eth45 = np.loadtxt('./Hist_contacts/phd_ncpH4tails_5.dat', usecols=(1), unpack=True, comments=('#'))
eth2a=np.concatenate((eth2a1[-700:],eth2a2[-700:],eth2a3[-700:],eth2a4[-700:],eth2a5[-700:]))
eth2b=np.concatenate((eth2b1[-700:],eth2b2[-700:],eth2b3[-700:],eth2b4[-700:],eth2b5[-700:]))
eth3=np.concatenate((eth31[-700:],eth32[-700:],eth33[-700:],eth34[-700:],eth35[-700:]))
eth4=np.concatenate((eth41[-700:],eth42[-700:],eth43[-700:],eth44[-700:],eth45[-700:]))

Eth2a1 = np.loadtxt('./Hist_contacts/bptf_ncpH2atails_1.dat', usecols=(1), unpack=True, comments=('#'))
Eth2a2 = np.loadtxt('./Hist_contacts/bptf_ncpH2atails_2.dat', usecols=(1), unpack=True, comments=('#'))
Eth2a3 = np.loadtxt('./Hist_contacts/bptf_ncpH2atails_3.dat', usecols=(1), unpack=True, comments=('#'))
Eth2a4 = np.loadtxt('./Hist_contacts/bptf_ncpH2atails_4.dat', usecols=(1), unpack=True, comments=('#'))
Eth2a5 = np.loadtxt('./Hist_contacts/bptf_ncpH2atails_5.dat', usecols=(1), unpack=True, comments=('#'))
Eth2b1 = np.loadtxt('./Hist_contacts/bptf_ncpH2btails_1.dat', usecols=(1), unpack=True, comments=('#'))
Eth2b2 = np.loadtxt('./Hist_contacts/bptf_ncpH2btails_2.dat', usecols=(1), unpack=True, comments=('#'))
Eth2b3 = np.loadtxt('./Hist_contacts/bptf_ncpH2btails_3.dat', usecols=(1), unpack=True, comments=('#'))
Eth2b4 = np.loadtxt('./Hist_contacts/bptf_ncpH2btails_4.dat', usecols=(1), unpack=True, comments=('#'))
Eth2b5 = np.loadtxt('./Hist_contacts/bptf_ncpH2btails_5.dat', usecols=(1), unpack=True, comments=('#'))
Eth31 = np.loadtxt('./Hist_contacts/bptf_ncpH3tails_1.dat', usecols=(1), unpack=True, comments=('#'))
Eth32 = np.loadtxt('./Hist_contacts/bptf_ncpH3tails_2.dat', usecols=(1), unpack=True, comments=('#'))
Eth33 = np.loadtxt('./Hist_contacts/bptf_ncpH3tails_3.dat', usecols=(1), unpack=True, comments=('#'))
Eth34 = np.loadtxt('./Hist_contacts/bptf_ncpH3tails_4.dat', usecols=(1), unpack=True, comments=('#'))
Eth35 = np.loadtxt('./Hist_contacts/bptf_ncpH3tails_5.dat', usecols=(1), unpack=True, comments=('#'))
Eth41 = np.loadtxt('./Hist_contacts/bptf_ncpH4tails_1.dat', usecols=(1), unpack=True, comments=('#'))
Eth42 = np.loadtxt('./Hist_contacts/bptf_ncpH4tails_2.dat', usecols=(1), unpack=True, comments=('#'))
Eth43 = np.loadtxt('./Hist_contacts/bptf_ncpH4tails_3.dat', usecols=(1), unpack=True, comments=('#'))
Eth44 = np.loadtxt('./Hist_contacts/bptf_ncpH4tails_4.dat', usecols=(1), unpack=True, comments=('#'))
Eth45 = np.loadtxt('./Hist_contacts/bptf_ncpH4tails_5.dat', usecols=(1), unpack=True, comments=('#'))
Eth2a=np.concatenate((Eth2a1[-700:],Eth2a2[-700:],Eth2a3[-700:],Eth2a4[-700:],Eth2a5[-700:]))
Eth2b=np.concatenate((Eth2b1[-700:],Eth2b2[-700:],Eth2b3[-700:],Eth2b4[-700:],Eth2b5[-700:]))
Eth3=np.concatenate((Eth31[-700:],Eth32[-700:],Eth33[-700:],Eth34[-700:],Eth35[-700:]))
Eth4=np.concatenate((Eth41[-700:],Eth42[-700:],Eth43[-700:],Eth44[-700:],Eth45[-700:]))


Mtail = np.array([stat.mean(mth2a), stat.mean(mth2b), stat.mean(mth3), stat.mean(mth4), stat.mean(mth2a+mth2b+mth3+mth4)])
Mterr = np.array([stat.stdev(mth2a)/2.2, stat.stdev(mth2b)/2.2, stat.stdev(mth3)/2.2, stat.stdev(mth4)/2.2, stat.stdev(mth2a+mth2b+mth3+mth4)/2.2])
Mcore = np.array([stat.mean(mh2a-mth2a), stat.mean(mh2b-mth2b), stat.mean(mh3-mth3), stat.mean(mh4-mth4),stat.mean(mh2a+mh2b+mh3+mh4-mth2a-mth2b-mth3-mth4)])
Mcerr = np.array([stat.stdev(mh2a-mth2a)/2.2, stat.stdev(mh2b-mth2b)/2.2, stat.stdev(mh3-mth3)/2.2, stat.stdev(mh4-mth4)/2.2, stat.stdev(mh2a+mh2b+mh3+mh4-mth2a-mth2b-mth3-mth4)/2.2])
Mall = np.array([stat.mean(mh2a), stat.mean(mh2b), stat.mean(mh3), stat.mean(mh4), stat.mean(mh2a+mh2b+mh3+mh4)])
Mallerr = np.array([stat.stdev(mh2a)/2.2, stat.stdev(mh2b)/2.2, stat.stdev(mh3)/2.2, stat.stdev(mh4)/2.2,stat.stdev(mh2a+mh2b+mh3+mh4)/2.2])

etail = np.array([stat.mean(eth2a), stat.mean(eth2b), stat.mean(eth3), stat.mean(eth4), stat.mean(eth2a+eth2b+eth3+eth4)])
eterr = np.array([stat.stdev(eth2a)/2.2, stat.stdev(eth2b)/2.2, stat.stdev(eth3)/2.2, stat.stdev(eth4)/2.2,stat.stdev(eth2a+eth2b+eth3+eth4)/2.2])
ecore = np.array([stat.mean(eh2a-eth2a), stat.mean(eh2b-eth2b), stat.mean(eh3-eth3), stat.mean(eh4-eth4),stat.mean(eh2a+eh2b+eh3+eh4-eth2a-eth2b-eth3-eth4)])
ecerr = np.array([stat.stdev(eh2a-eth2a)/2.2, stat.stdev(eh2b-eth2b)/2.2, stat.stdev(eh3-eth3)/2.2, stat.stdev(eh4-eth4)/2.2,stat.stdev(eh2a+eh2b+eh3+eh4-eth2a-eth2b-eth3-eth4)/2.2])
eall = np.array([stat.mean(eh2a), stat.mean(eh2b), stat.mean(eh3), stat.mean(eh4),stat.mean(eh2a+eh2b+eh3+eh4)])
eallerr = np.array([stat.stdev(eh2a)/2.2, stat.stdev(eh2b)/2.2, stat.stdev(eh3)/2.2, stat.stdev(eh4)/2.2,stat.stdev(eh2a+eh2b+eh3+eh4)/2.2])

Etail = np.array([stat.mean(Eth2a), stat.mean(Eth2b), stat.mean(Eth3), stat.mean(Eth4),stat.mean(Eth2a+Eth2b+Eth3+Eth4)])
Eterr = np.array([stat.stdev(Eth2a)/2.2, stat.stdev(Eth2b)/2.2, stat.stdev(Eth3)/2.2, stat.stdev(Eth4)/2.2,stat.stdev(Eth2a+Eth2b+Eth3+Eth4)/2.2])
Ecore = np.array([stat.mean(Eh2a-Eth2a), stat.mean(Eh2b-Eth2b), stat.mean(Eh3-Eth3), stat.mean(Eh4-Eth4),stat.mean(Eh2a+Eh2b+Eh3+Eh4-Eth2a-Eth2b-Eth3-Eth4)])
Ecerr = np.array([stat.stdev(Eh2a-Eth2a)/2.2, stat.stdev(Eh2b-Eth2b)/2.2, stat.stdev(Eh3-Eth3)/2.2, stat.stdev(Eh4-Eth4)/2.2,stat.stdev(Eh2a+Eh2b+Eh3+Eh4-Eth2a-Eth2b-Eth3-Eth4)/2.2])
Eall = np.array([stat.mean(Eh2a), stat.mean(Eh2b), stat.mean(Eh3), stat.mean(Eh4),stat.mean(Eh2a+Eh2b+Eh3+Eh4)])
Eallerr = np.array([stat.stdev(Eh2a)/2.2, stat.stdev(Eh2b)/2.2, stat.stdev(Eh3)/2.2, stat.stdev(Eh4)/2.2,stat.stdev(Eh2a+Eh2b+Eh3+Eh4)/2.2])

list = ['H2A','H2B','H3','H4', 'Total']

# %%
# Three figures - Tails, core, then total

fig, axs = plt.subplots(2,2,figsize=(6, 6))
width = 0.25
l2 = np.arange(1,6,1)
#plt.bar(list, h4, width, bottom = h3 + h2a + h2b, label='H4', color='green')
#plt.bar(list, h3, width, bottom = h2a + h2b, label='H3', color='blue')
#plt.bar(list, h2b, width, bottom = h2a, label='H2b', color='red')
#plt.bar(list, h2a, width, label='H2a', color='yellow')
axs[0,0].bar(l2[0] - width, height=Mcore[0], yerr=Mcerr[0], width=width, label='NCP core', color='black', alpha=0.7,capsize=1.5)
axs[0,0].bar(l2[0] - width, height=Mtail[0], yerr=Mterr[0], bottom=Mcore[0], width=width, label='NCP tails', color='black', alpha=0.3, capsize=1.5)
axs[0,0].bar(l2[0], ecore[0], yerr=ecerr[0], width=width, label='NCP+PHD core', color='blue', capsize=1.5)
axs[0,0].bar(l2[0], etail[0], yerr=eterr[0], bottom=ecore[0],width=width, label='NCP+PHD tails', color='cyan', alpha=0.5, capsize=1.5)
axs[0,0].bar(l2[0] + width, Ecore[0], yerr=Ecerr[0], width=width, label='NCP+BPTF', color='red', capsize=1.5)
axs[0,0].bar(l2[0] + width, Etail[0], yerr=Eterr[0], bottom=Ecore[0],width=width, label='NCP+BPTF', color='pink', alpha=0.5, capsize=1.5)
axs[0,0].set_ylabel('Contacts')
axs[0,0].set_xticks(ticks=(l2[0] - width, l2[0], l2[0]+width), labels=[])
axs[0,0].set_title('H2A - DNA Contacts')
#axs[0,0].legend(loc='upper left')

axs[0,1].bar(l2[1] - width, height=Mcore[1], yerr=Mcerr[1], width=width, label='NCP core', color='black', alpha=0.7,capsize=1.5)
axs[0,1].bar(l2[1] - width, height=Mtail[1], yerr=Mterr[1], bottom=Mcore[1], width=width, label='NCP tails', color='black', alpha=0.3, capsize=1.5)
axs[0,1].bar(l2[1], ecore[1], yerr=ecerr[1], width=width, label='NCP+PHD core', color='blue', capsize=1.5)
axs[0,1].bar(l2[1], etail[1], yerr=eterr[1], bottom=ecore[1],width=width, label='NCP+PHD tails', color='cyan', alpha=0.5, capsize=1.5)
axs[0,1].bar(l2[1] + width, Ecore[1], yerr=Ecerr[1], width=width, label='NCP+BPTF core', color='red', capsize=1.5)
axs[0,1].bar(l2[1] + width, Etail[1], yerr=Eterr[1], bottom=Ecore[1],width=width, label='NCP+BPTF tails', color='pink', alpha=0.5, capsize=1.5)
axs[0,1].set_xticks(ticks=(l2[1] - width, l2[1], l2[1]+width), labels=[])
axs[0,1].set_title('H2B - DNA Contacts')

axs[1,0].bar(l2[2] - width, height=Mcore[2], yerr=Mcerr[2], width=width, label='NCP core', color='black', alpha=0.7,capsize=1.5)
axs[1,0].bar(l2[2] - width, height=Mtail[2], yerr=Mterr[2], bottom=Mcore[2], width=width, label='NCP tails', color='black', alpha=0.3, capsize=1.5)
axs[1,0].bar(l2[2], ecore[2], yerr=ecerr[2], width=width, label='NCP+PHD core', color='blue', capsize=1.5)
axs[1,0].bar(l2[2], etail[2], yerr=eterr[2], bottom=ecore[2],width=width, label='NCP+PHD tails', color='cyan', alpha=0.5, capsize=1.5)
axs[1,0].bar(l2[2] + width, Ecore[2], yerr=Ecerr[2], width=width, label='NCP+BPTF', color='red', capsize=1.5)
axs[1,0].bar(l2[2] + width, Etail[2], yerr=Eterr[2], bottom=Ecore[2],width=width, label='NCP+BPTF', color='pink', alpha=0.5, capsize=1.5)
axs[1,0].set_ylabel('Contacts')
axs[1,0].set_xticks(ticks=(l2[2] - width, l2[2], l2[2]+width), labels=('NCP','NCP + PHD','NCP + BPTF'), fontsize=10, rotation=45)
axs[1,0].set_title('H3 - DNA Contacts')

axs[1,1].bar(l2[3] - width, height=Mcore[3], yerr=Mcerr[3], width=width, label='NCP core', color='black', alpha=0.7,capsize=1.5)
axs[1,1].bar(l2[3] - width, height=Mtail[3], yerr=Mterr[3], bottom=Mcore[3], width=width, label='NCP tails', color='black', alpha=0.3, capsize=1.5)
axs[1,1].bar(l2[3], ecore[3], yerr=ecerr[3], width=width, label='NCP+PHD core', color='blue', capsize=1.5)
axs[1,1].bar(l2[3], etail[3], yerr=eterr[3], bottom=ecore[3],width=width, label='NCP+PHD tails', color='cyan', alpha=0.5, capsize=1.5)
axs[1,1].bar(l2[3] + width, Ecore[3], yerr=Ecerr[3], width=width, label='NCP+BPTF', color='red', capsize=1.5)
axs[1,1].bar(l2[3] + width, Etail[3], yerr=Eterr[3], bottom=Ecore[3],width=width, label='NCP+BPTF', color='pink', alpha=0.5, capsize=1.5)
axs[1,1].set_xticks(ticks=(l2[3] - width, l2[3], l2[3]+width), labels=('NCP','NCP + PHD','NCP + BPTF'), fontsize=10, rotation=45)
axs[1,1].set_title('H4 - DNA Contacts')
#axs[0,1].legend(bbox_to_anchor=(1.0, 0.75), fontsize=10)
plt.suptitle('Histone - DNA Average Contacts')
plt.tight_layout()
plt.savefig('hist_dna_dif_4x4.pdf', dpi=300)

# %%
# H2A, H2B, H3, H4, All
hist = ['H2A:','H2B:','H3:','H4:','Total:']
print('NCP tails:')
for i in np.arange(0,5):
    print(f'{hist[i]} {int(np.round(Mtail[i]))} +/- {str(int(np.round(Mterr[i])))}')
print('\nEnoB tails:')
for i in np.arange(0,5):
    print(f'{hist[i]} {int(np.round(etail[i]))} +/- {str(int(np.round(eterr[i])))}')
print('\nNucE tails:')
for i in np.arange(0,5):
    print(f'{hist[i]} {int(np.round(Etail[i]))} +/- {str(int(np.round(Eterr[i])))}')
# Out:
# NCP tails:
# H2A: 382 +/- 27
# H2B: 637 +/- 40
# H3: 480 +/- 54
# H4: 297 +/- 40
# Total: 1796 +/- 87
#
# EnoB tails:
# H2A: 430 +/- 53
# H2B: 673 +/- 36
# H3: 377 +/- 40
# H4: 381 +/- 44
# Total: 1862 +/- 78
#
# NucE tails:
# H2A: 458 +/- 31
# H2B: 645 +/- 34
# H3: 394 +/- 43
# H4: 345 +/- 32
# Total: 1842 +/- 74

# %%
# H2A, H2B, H3, H4, All
print('NCP core:')
for i in np.arange(0,5):
    print(f'{hist[i]} {int(np.round(Mcore[i]))} +/- {str(int(np.round(Mcerr[i])))}')

print('\nEnoB core:')
for i in np.arange(0,5):
    print(f'{hist[i]} {int(np.round(ecore[i]))} +/- {str(int(np.round(ecerr[i])))}')
print('\nNucE core:')
for i in np.arange(0,5):
    print(f'{hist[i]} {int(np.round(Ecore[i]))} +/- {str(int(np.round(Ecerr[i])))}')
# Out:
# NCP core:
# H2A: 547 +/- 33
# H2B: 170 +/- 16
# H3: 1019 +/- 30
# H4: 437 +/- 11
# Total: 2174 +/- 44
#
# EnoB core:
# H2A: 571 +/- 30
# H2B: 196 +/- 10
# H3: 1009 +/- 40
# H4: 420 +/- 11
# Total: 2196 +/- 52
#
# NucE core:
# H2A: 546 +/- 30
# H2B: 192 +/- 10
# H3: 1001 +/- 31
# H4: 419 +/- 11
# Total: 2158 +/- 52

# %%
print('NCP total:')
for i in np.arange(0,5):
    print(f'{hist[i]} {int(np.round(Mall[i]))} +/- {str(int(np.round(Mallerr[i])))}')
print('\nEnoB total:')
for i in np.arange(0,5):
    print(f'{hist[i]} {int(np.round(eall[i]))} +/- {str(int(np.round(eallerr[i])))}')
print('\nNucE total:')
for i in np.arange(0,5):
    print(f'{hist[i]} {int(np.round(Eall[i]))} +/- {str(int(np.round(Eallerr[i])))}')
# Out:
# NCP total:
# H2A: 929 +/- 40
# H2B: 807 +/- 44
# H3: 1500 +/- 66
# H4: 734 +/- 42
# Total: 3970 +/- 99
#
# EnoB total:
# H2A: 1001 +/- 67
# H2B: 869 +/- 39
# H3: 1386 +/- 57
# H4: 801 +/- 47
# Total: 4057 +/- 103
#
# NucE total:
# H2A: 1004 +/- 48
# H2B: 836 +/- 36
# H3: 1396 +/- 51
# H4: 763 +/- 35
# Total: 4000 +/- 92
