# %%
import pandas as pd
import re
from math import sqrt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

filename1 = "E1gbsa.txt"
filename2 = "E2gbsa.txt"
filename3 = "E3gbsa.txt"
filename4 = "E4gbsa.txt"
filename5 = "E5gbsa.txt"

f1 = "EnoB1gbsa.txt"
f2 = "EnoB2gbsa.txt"
f3 = "EnoB3gbsa.txt"
f4 = "EnoB4gbsa.txt"
f5 = "EnoB5gbsa.txt"

m1 = "M1gbsa.txt"
m2 = "M2gbsa.txt"
m3 = "M3gbsa.txt"
m4 = "M4gbsa.txt"
m5 = "M5gbsa.txt"
# Pattern: match any line that has 6 columns with "value +/- error"
value_pattern = re.compile(r"([-\d.Ee]+)\s+\+/-\s+([-\d.Ee]+)")

data1 = []
data2 = []
data3 = []
data4 = []
data5 = []

d1 = []
d2 = []
d3 = []
d4 = []
d5 = []

dm1 = []
dm2 = []
dm3 = []
dm4 = []
dm5 = []
failures = []

with open(filename1) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data1.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename2) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data2.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename3) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data3.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename4) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data4.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename5) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data5.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f1) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d1.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f2) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d2.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f3) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d3.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f4) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d4.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f5) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d5.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(m1) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    dm1.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(m2) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    dm2.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(m3) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    dm3.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(m4) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    dm4.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(m5) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    dm5.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

# Define column headers
columns = [
    "Residue",
    "Internal", "Internal_err",
    "VDW", "VDW_err",
    "Electrostatic", "Electrostatic_err",
    "Polar", "Polar_err",
    "NonPolar", "NonPolar_err",
    "Total", "Total_err"
]

df1 = pd.DataFrame(data1, columns=columns)
df2 = pd.DataFrame(data2, columns=columns)
df3 = pd.DataFrame(data3, columns=columns)
df4 = pd.DataFrame(data4, columns=columns)
df5 = pd.DataFrame(data5, columns=columns)

df6 = pd.DataFrame(d1, columns=columns)
df7 = pd.DataFrame(d2, columns=columns)
df8 = pd.DataFrame(d3, columns=columns)
df9 = pd.DataFrame(d4, columns=columns)
df10 = pd.DataFrame(d5, columns=columns)

df11 = pd.DataFrame(dm1, columns=columns)
df12 = pd.DataFrame(dm2, columns=columns)
df13 = pd.DataFrame(dm3, columns=columns)
df14 = pd.DataFrame(dm4, columns=columns)
df15 = pd.DataFrame(dm5, columns=columns)
# ✅ Summary
print(f"✅ Parsed {len(df1)} residues.")
print(df1.head())

# Optional debug
if failures:
    print(f"\n⚠️ Skipped {len(failures)} lines. First 5:")
    for f in failures[:5]:
        print(f)
# Out:
# ✅ Parsed 317 residues.
#   Residue  Internal  Internal_err  VDW  VDW_err  Electrostatic  \
# 0    DA51       0.0           0.0 -0.0      0.0         -7.454
# 1     DT2       0.0           0.0 -0.0      0.0        -23.782
# 2     DC3       0.0           0.0 -0.0      0.0        -23.477
# 3     DA4       0.0           0.0 -0.0      0.0        -23.667
# 4     DA5       0.0           0.0 -0.0      0.0        -24.431
#
#    Electrostatic_err   Polar  Polar_err  NonPolar  NonPolar_err  Total  \
# 0              0.382   7.453      0.382       0.0           0.0 -0.000
# 1              1.020  23.781      1.020       0.0           0.0 -0.001
# 2              1.008  23.476      1.008       0.0           0.0 -0.001
# 3              0.924  23.667      0.924       0.0           0.0 -0.001
# 4              0.914  24.431      0.914       0.0           0.0 -0.001
#
#    Total_err
# 0      0.001
# 1      0.001
# 2      0.001
# 3      0.001
# 4      0.001
#
# ⚠️ Skipped 45 lines. First 5:
# Wrong # of value/error pairs: | Run on Fri Apr 25 21:54:57 2025
# Wrong # of value/error pairs: || GB non-polar solvation energies calculated with gbsa=2
# Wrong # of value/error pairs: Residue |  Location |       Internal      |    van der Waals    |    Electrostatic    |   Polar Solvation   |    Non-Polar Solv.  |       TOTAL
# Wrong # of value/error pairs: | Run on Fri Apr 25 23:10:25 2025
# Wrong # of value/error pairs: || GB non-polar solvation energies calculated with gbsa=2

# %%
df6
# Out:
#     Residue  Internal  Internal_err    VDW  VDW_err  Electrostatic  \
# 0      DA51       0.0           0.0 -0.000    0.000         -7.241
# 1       DT2       0.0           0.0 -0.000    0.000        -23.547
# 2       DC3       0.0           0.0 -0.000    0.000        -23.757
# 3       DA4       0.0           0.0 -0.000    0.000        -24.292
# 4       DA5       0.0           0.0 -0.000    0.000        -25.509
# ..      ...       ...           ...    ...      ...            ...
# 312  ARG313       0.0           0.0 -1.742    1.663       -951.273
# 313  LYS314       0.0           0.0 -0.697    0.754       -960.680
# 314  VAL315       0.0           0.0 -0.291    0.311          6.323
# 315  LEU316       0.0           0.0 -0.245    0.397         -5.074
# 316  ARG317       0.0           0.0 -1.056    0.918      -1094.538
#
#      Electrostatic_err     Polar  Polar_err  NonPolar  NonPolar_err  Total  \
# 0                0.343     7.241      0.343     0.000         0.000 -0.000
# 1                1.069    23.546      1.068     0.000         0.000 -0.001
# 2                0.895    23.757      0.895     0.000         0.000 -0.001
# 3                0.853    24.292      0.853     0.000         0.000 -0.001
# 4                0.906    25.508      0.906     0.000         0.000 -0.001
# ..                 ...       ...        ...       ...           ...    ...
# 312             64.359   950.981     64.498    -0.313         0.263 -2.347
# 313             66.516   960.146     66.323    -0.129         0.145 -1.360
# 314              4.016    -6.223      3.917    -0.024         0.040 -0.214
# 315              5.212     5.172      5.236    -0.039         0.093 -0.186
# 316             27.039  1094.347     27.747    -0.462         0.216 -1.710
#
#      Total_err
# 0        0.001
# 1        0.001
# 2        0.001
# 3        0.001
# 4        0.001
# ..         ...
# 312      2.041
# 313      1.253
# 314      0.602
# 315      0.439
# 316      1.411
#
# [317 rows x 13 columns]

# %%
# Ensure each df has a numeric residue ID column
for df in [df1, df2, df3, df4, df5]:
    df["ResID"] = df["Residue"].str.extract(r"(\d+)$").astype(int)

# Extract Total energy for residues 295–317 from each df
dfs = []
for i, df in enumerate([df1, df2, df3, df4, df5], start=1):
    subset = df[(df["ResID"] >= 295) & (df["ResID"] <= 317)].copy()
    subset = subset[["Residue", "Total"]].rename(columns={"Total": f"Total_{i}"})
    dfs.append(subset)

# Merge on Residue
merged = dfs[0]
for df in dfs[1:]:
    merged = pd.merge(merged, df, on="Residue")

# Calculate mean and std across the 5 Total columns
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 6)]].mean(axis=1)
merged["Total_std"] = merged[[f"Total_{i}" for i in range(1, 6)]].std(axis=1)

# After merging the Total columns:

# Also merge Total_err columns from each df
for i, df in enumerate([df1, df2, df3, df4, df5], start=1):
    subset_err = df[(df["ResID"] >= 295) & (df["ResID"] <= 317)].copy()
    subset_err = subset_err[["Residue", "Total_err"]].rename(columns={"Total_err": f"Total_err_{i}"})
    merged = pd.merge(merged, subset_err, on="Residue")

# Calculate mean of Total values (same as before)
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 6)]].mean(axis=1)

# Propagate the standard deviations of the Total_err columns
# Standard error of the mean = sqrt(sum of variances) / N
merged["Total_err_propagated"] = np.sqrt(
    np.sum(np.square(merged[[f"Total_err_{i}" for i in range(1, 6)]]), axis=1)
) / 5

# Final result with propagated error
result = merged[["Residue", "Total_mean", "Total_err_propagated"]]

print(result)
# Out:
#    Residue  Total_mean  Total_err_propagated
# 0   SER295      2.5792              2.038313
# 1   GLY296     -0.4504              0.344083
# 2   ARG297     -2.0668              0.900961
# 3   GLY298     -0.4340              0.436375
# 4   LYS299      0.0044              1.092763
# 5   GLY300     -0.2888              0.320334
# 6   GLY301     -0.5016              0.357384
# 7   LYS302     -0.2976              1.168243
# 8   GLY303     -0.3582              0.269492
# 9   LEU304     -0.5340              0.380248
# 10  GLY305     -0.0618              0.275510
# 11  LYS306      0.0520              1.007147
# 12  GLY307     -0.4618              0.355753
# 13  GLY308     -0.3532              0.400824
# 14  ALA309     -0.3222              0.371860
# 15  LYS310      2.3470              1.696373
# 16  ARG311     -2.9058              0.742286
# 17  HIE312      0.0252              0.121891
# 18  ARG313     -1.3290              0.480329
# 19  LYS314     -0.7972              0.302275
# 20  VAL315     -0.0902              0.127943
# 21  LEU316     -0.1576              0.147076
# 22  ARG317     -1.0664              0.402970

# %%
# Ensure each df has a numeric residue ID column
for df in [df6, df7, df8, df9, df10]:
    df["ResID"] = df["Residue"].str.extract(r"(\d+)$").astype(int)

# Extract Total energy for residues 295–317 from each df
df2s = []
for i, df in enumerate([df6, df7, df8, df9, df10], start=1):
    subset = df[(df["ResID"] >= 295) & (df["ResID"] <= 317)].copy()
    subset = subset[["Residue", "Total"]].rename(columns={"Total": f"Total_{i}"})
    df2s.append(subset)

# Merge on Residue
merged = df2s[0]
for df in df2s[1:]:
    merged = pd.merge(merged, df, on="Residue")

# Calculate mean and std across the 5 Total columns
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 6)]].mean(axis=1)
merged["Total_std"] = merged[[f"Total_{i}" for i in range(1, 6)]].std(axis=1)

# After merging the Total columns:

# Also merge Total_err columns from each df
for i, df in enumerate([df6, df7, df8, df9, df10], start=1):
    subset_err = df[(df["ResID"] >= 295) & (df["ResID"] <= 317)].copy()
    subset_err = subset_err[["Residue", "Total_err"]].rename(columns={"Total_err": f"Total_err_{i}"})
    merged = pd.merge(merged, subset_err, on="Residue")

# Calculate mean of Total values (same as before)
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 6)]].mean(axis=1)

# Propagate the standard deviations of the Total_err columns
# Standard error of the mean = sqrt(sum of variances) / N
merged["Total_err_propagated"] = np.sqrt(
    np.sum(np.square(merged[[f"Total_err_{i}" for i in range(1, 6)]]), axis=1)
) / 5

# Final result with propagated error
result2 = merged[["Residue", "Total_mean", "Total_err_propagated"]]

print(result2)
# Out:
#    Residue  Total_mean  Total_err_propagated
# 0   SER295      2.8730              1.889743
# 1   GLY296     -0.4070              0.398214
# 2   ARG297     -2.6474              1.007315
# 3   GLY298     -0.3746              0.449017
# 4   LYS299      0.9544              1.420236
# 5   GLY300     -0.6802              0.365666
# 6   GLY301     -0.8326              0.391985
# 7   LYS302     -0.5992              1.090801
# 8   GLY303     -0.3662              0.269802
# 9   LEU304     -0.5534              0.439978
# 10  GLY305     -0.1352              0.229258
# 11  LYS306      0.5594              1.323007
# 12  GLY307     -0.2220              0.262046
# 13  GLY308     -0.1628              0.244889
# 14  ALA309     -0.1420              0.295452
# 15  LYS310     -0.5670              0.824404
# 16  ARG311     -1.6876              0.803860
# 17  HIE312     -0.5038              0.365136
# 18  ARG313     -1.9768              0.825418
# 19  LYS314     -0.8322              0.476159
# 20  VAL315     -0.3084              0.223651
# 21  LEU316     -0.3572              0.199044
# 22  ARG317     -1.6504              0.458201

# %%
# Ensure each df has a numeric residue ID column
for df in [df11, df12, df13, df14, df15]:
    df["ResID"] = df["Residue"].str.extract(r"(\d+)$").astype(int)

# Extract Total energy for residues 295–317 from each df
df2s = []
for i, df in enumerate([df11, df12, df13, df14, df15], start=1):
    subset = df[(df["ResID"] >= 295) & (df["ResID"] <= 317)].copy()
    subset = subset[["Residue", "Total"]].rename(columns={"Total": f"Total_{i}"})
    df2s.append(subset)

# Merge on Residue
merged = df2s[0]
for df in df2s[1:]:
    merged = pd.merge(merged, df, on="Residue")

# Calculate mean and std across the 5 Total columns
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 6)]].mean(axis=1)
merged["Total_std"] = merged[[f"Total_{i}" for i in range(1, 6)]].std(axis=1)

# After merging the Total columns:

# Also merge Total_err columns from each df
for i, df in enumerate([df11, df12, df13, df14, df15], start=1):
    subset_err = df[(df["ResID"] >= 295) & (df["ResID"] <= 317)].copy()
    subset_err = subset_err[["Residue", "Total_err"]].rename(columns={"Total_err": f"Total_err_{i}"})
    merged = pd.merge(merged, subset_err, on="Residue")

# Calculate mean of Total values (same as before)
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 6)]].mean(axis=1)

# Propagate the standard deviations of the Total_err columns
# Standard error of the mean = sqrt(sum of variances) / N
merged["Total_err_propagated"] = np.sqrt(
    np.sum(np.square(merged[[f"Total_err_{i}" for i in range(1, 6)]]), axis=1)
) / 5

# Final result with propagated error
result3 = merged[["Residue", "Total_mean", "Total_err_propagated"]]

print(result3)
# Out:
#    Residue  Total_mean  Total_err_propagated
# 0   SER295      1.6396              1.325060
# 1   GLY296     -0.2648              0.300797
# 2   ARG297     -1.9338              0.744233
# 3   GLY298     -0.4838              0.349347
# 4   LYS299      0.0668              1.312708
# 5   GLY300     -0.2708              0.291961
# 6   GLY301     -0.3346              0.290135
# 7   LYS302      1.4948              1.708013
# 8   GLY303     -0.3642              0.251003
# 9   LEU304     -0.5098              0.467379
# 10  GLY305     -0.1622              0.260087
# 11  LYS306     -0.6522              0.649845
# 12  GLY307     -0.2416              0.271509
# 13  GLY308     -0.1978              0.243914
# 14  ALA309     -0.1580              0.226118
# 15  LYS310     -0.2744              0.689051
# 16  ARG311     -1.3896              0.587164
# 17  HIE312     -0.2362              0.401929
# 18  ARG313     -1.0934              0.469086
# 19  LYS314     -0.5812              0.426944
# 20  VAL315     -0.0252              0.045792
# 21  LEU316     -0.0768              0.098817
# 22  ARG317     -1.3672              0.375084

# %%
avg1 = np.array(result['Total_mean'])
avg2 = np.array(result2['Total_mean'])
avg3 = np.array(result3['Total_mean'])

std = np.array(result['Total_err_propagated'])
std2 = np.array(result2['Total_err_propagated'])
std3 = np.array(result3['Total_err_propagated'])

ste1 = std/sqrt(5)
ste2 = std2/sqrt(5)
ste3 = std3/sqrt(5)

# %%
width = 0.25
list = ['S1', 'G2', 'R3', 'G3', 'K5', 'G6', 'G7', 'K8', 'G9', 'L10', 'G11', 'K12', 'G13', 'G14', 'A15', 'K16', 'R17', 'H18', 'R19', 'K20', 'V21', 'L22', 'R23']
plt.figure(figsize=(6, 3))
plt.bar(x=np.arange(1,24,1)-width, height=avg3, yerr=ste3, width=width, label = "NCP", color='gray')
plt.bar(x=np.arange(1,24,1), height=avg2, yerr=ste2, width=width, label = "NCP + PHD", color='blue')
plt.bar(x=np.arange(1,24,1)+width, height=avg1, yerr=ste1, width=width, label = "NCP + BPTF", color='red')
plt.axhline(y=0, color='black')
plt.xticks(np.arange(1,len(list)+1), list, rotation=90)
plt.ylim(-3.3,10.5)
plt.title('H4 Tail - DNA Binding Energy')
#plt.xlabel('Residue')
plt.ylabel('Binding Energy (kcal/mol)')
plt.legend(loc='upper right')

plt.savefig('H4.1_dna_gbsa_byres.pdf')

# %%
np.sum(avg1)
# Out:
# -7.468800000000001

# %%
np.sum(avg2)
# Out:
# -10.619200000000001

# %%
np.sum(avg3)
# Out:
# -7.416399999999999

# %%
np.sum(df15['Total'])
# Out:
# -29.22699999999999
