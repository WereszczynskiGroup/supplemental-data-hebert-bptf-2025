# %%
import matplotlib.pyplot as plt
import numpy as np
import statistics as stat

# %%
# NucE

x, yh3dna1 = np.loadtxt('./Hbonds/bptf_ncpdnah3bond1series.dat', usecols = (0,1), unpack = True, comments=('#'))
ydna1 = np.loadtxt('./Hbonds/bptf_ncpdnaseries1.dat', usecols = (1), unpack = True, comments=('#'))
y1h3 = np.loadtxt('./Hbonds/bptf_ncph3bond1series.dat', usecols=(1),unpack=True,comments=('#'))

yh3dna2 = np.loadtxt('./Hbonds/bptf_ncpdnah3bond2series.dat', usecols = (1), unpack = True, comments=('#'))
ydna2 = np.loadtxt('./Hbonds/bptf_ncpdnaseries2.dat', usecols = (1), unpack = True, comments=('#'))
y2h3 = np.loadtxt('./Hbonds/bptf_ncph3bond2series.dat', usecols=(1),unpack=True,comments=('#'))

yh3dna3 = np.loadtxt('./Hbonds/bptf_ncpdnah3bond3series.dat', usecols = (1), unpack = True, comments=('#'))
ydna3 = np.loadtxt('./Hbonds/bptf_ncpdnaseries3.dat', usecols = (1), unpack = True, comments=('#'))
y3h3 = np.loadtxt('./Hbonds/bptf_ncph3bond3series.dat', usecols=(1),unpack=True,comments=('#'))

yh3dna4 = np.loadtxt('./Hbonds/bptf_ncpdnah3bond4series.dat', usecols = (1), unpack = True, comments=('#'))
ydna4 = np.loadtxt('./Hbonds/bptf_ncpdnaseries4.dat', usecols = (1), unpack = True, comments=('#'))
y4h3 = np.loadtxt('./Hbonds/bptf_ncph3bond4series.dat', usecols=(1),unpack=True,comments=('#'))

yh3dna5 = np.loadtxt('./Hbonds/bptf_ncpdnah3bond5series.dat', usecols = (1), unpack = True, comments=('#'))
ydna5 = np.loadtxt('./Hbonds/bptf_ncpdnaseries5.dat', usecols = (1), unpack = True, comments=('#'))
y5h3 = np.loadtxt('./Hbonds/bptf_ncph3bond5series.dat', usecols=(1),unpack=True,comments=('#'))

y1 = yh3dna1 - ydna1 - y1h3
y2 = yh3dna2 - ydna2 - y2h3
y3 = yh3dna3 - ydna3 - y3h3
y4 = yh3dna4 - ydna4 - y4h3
y5 = yh3dna5 - ydna5 - y5h3
EH3 = np.concatenate((y1,y2,y3,y4,y5))


ah4_1 = np.loadtxt('./Hbonds/bptf_ncpdnah4bond1series.dat', usecols = (1), unpack = True, comments=('#'))
a1h4 = np.loadtxt('./Hbonds/bptf_ncph4bond1series.dat', usecols=(1),unpack=True,comments=('#'))
ah4_2 = np.loadtxt('./Hbonds/bptf_ncpdnah4bond2series.dat', usecols = (1), unpack = True, comments=('#'))
a2h4 = np.loadtxt('./Hbonds/bptf_ncph4bond2series.dat', usecols=(1),unpack=True,comments=('#'))
ah4_3 = np.loadtxt('./Hbonds/bptf_ncpdnah4bond3series.dat', usecols = (1), unpack = True, comments=('#'))
a3h4 = np.loadtxt('./Hbonds/bptf_ncph4bond3series.dat', usecols=(1),unpack=True,comments=('#'))
ah4_4 = np.loadtxt('./Hbonds/bptf_ncpdnah4bond4series.dat', usecols = (1), unpack = True, comments=('#'))
a4h4 = np.loadtxt('./Hbonds/bptf_ncph4bond4series.dat', usecols=(1),unpack=True,comments=('#'))
ah4_5 = np.loadtxt('./Hbonds/bptf_ncpdnah4bond5series.dat', usecols = (1), unpack = True, comments=('#'))
a5h4 = np.loadtxt('./Hbonds/bptf_ncph4bond5series.dat', usecols=(1),unpack=True,comments=('#'))

a1 = ah4_1 - ydna1 - a1h4
a2 = ah4_2 - ydna2 - a2h4
a3 = ah4_3 - ydna3 - a3h4
a4 = ah4_4 - ydna4 - a4h4
a5 = ah4_5 - ydna5 - a5h4
EH4 = np.concatenate((a1,a2,a3,a4,a5))

bh2a_1 = np.loadtxt('./Hbonds/bptf_ncpdnah2abond1series.dat', usecols = (1), unpack = True, comments=('#'))
b1h2a = np.loadtxt('./Hbonds/bptf_ncph2abond1series.dat', usecols=(1),unpack=True,comments=('#'))
bh2a_2 = np.loadtxt('./Hbonds/bptf_ncpdnah2abond2series.dat', usecols = (1), unpack = True, comments=('#'))
b2h2a = np.loadtxt('./Hbonds/bptf_ncph2abond2series.dat', usecols=(1),unpack=True,comments=('#'))
bh2a_3 = np.loadtxt('./Hbonds/bptf_ncpdnah2abond3series.dat', usecols = (1), unpack = True, comments=('#'))
b3h2a = np.loadtxt('./Hbonds/bptf_ncph2abond3series.dat', usecols=(1),unpack=True,comments=('#'))
bh2a_4 = np.loadtxt('./Hbonds/bptf_ncpdnah2abond4series.dat', usecols = (1), unpack = True, comments=('#'))
b4h2a = np.loadtxt('./Hbonds/bptf_ncph2abond4series.dat', usecols=(1),unpack=True,comments=('#'))
bh2a_5 = np.loadtxt('./Hbonds/bptf_ncpdnah2abond5series.dat', usecols = (1), unpack = True, comments=('#'))
b5h2a = np.loadtxt('./Hbonds/bptf_ncph2abond5series.dat', usecols=(1),unpack=True,comments=('#'))

b1 = bh2a_1 - ydna1 - b1h2a
b2 = bh2a_2 - ydna2 - b2h2a
b3 = bh2a_3 - ydna3 - b3h2a
b4 = bh2a_4 - ydna4 - b4h2a
b5 = bh2a_5 - ydna5 - b5h2a
EH2a = np.concatenate((b1,b2,b3,b4,b5))

ch2b_1 = np.loadtxt('./Hbonds/bptf_ncpdnah2bbond1series.dat', usecols = (1), unpack = True, comments=('#'))
c1h2b = np.loadtxt('./Hbonds/bptf_ncph2bbond1series.dat', usecols=(1),unpack=True,comments=('#'))
ch2b_2 = np.loadtxt('./Hbonds/bptf_ncpdnah2bbond2series.dat', usecols = (1), unpack = True, comments=('#'))
c2h2b = np.loadtxt('./Hbonds/bptf_ncph2bbond2series.dat', usecols=(1),unpack=True,comments=('#'))
ch2b_3 = np.loadtxt('./Hbonds/bptf_ncpdnah2bbond3series.dat', usecols = (1), unpack = True, comments=('#'))
c3h2b = np.loadtxt('./Hbonds/bptf_ncph2bbond3series.dat', usecols=(1),unpack=True,comments=('#'))
ch2b_4 = np.loadtxt('./Hbonds/bptf_ncpdnah2bbond4series.dat', usecols = (1), unpack = True, comments=('#'))
c4h2b = np.loadtxt('./Hbonds/bptf_ncph2bbond4series.dat', usecols=(1),unpack=True,comments=('#'))
ch2b_5 = np.loadtxt('./Hbonds/bptf_ncpdnah2bbond5series.dat', usecols = (1), unpack = True, comments=('#'))
c5h2b = np.loadtxt('./Hbonds/bptf_ncph2bbond5series.dat', usecols=(1),unpack=True,comments=('#'))

c1 = ch2b_1 - ydna1 - c1h2b
c2 = ch2b_2 - ydna2 - c2h2b
c3 = ch2b_3 - ydna3 - c3h2b
c4 = ch2b_4 - ydna4 - c4h2b
c5 = ch2b_5 - ydna5 - c5h2b
EH2b = np.concatenate((c1,c2,c3,c4,c5))

# NucE, H3

y1h3_1 = np.loadtxt('./Hbonds/bptf_ncptail1h31.dat', usecols = (1), unpack = True, comments=('#'))
y1h3_2 = np.loadtxt('./Hbonds/bptf_ncptail2h31.dat', usecols=(1),unpack=True,comments=('#'))
y2h3_1 = np.loadtxt('./Hbonds/bptf_ncptail1h32.dat', usecols = (1), unpack = True, comments=('#'))
y2h3_2 = np.loadtxt('./Hbonds/bptf_ncptail2h32.dat', usecols=(1),unpack=True,comments=('#'))
y3h3_1 = np.loadtxt('./Hbonds/bptf_ncptail1h33.dat', usecols = (1), unpack = True, comments=('#'))
y3h3_2 = np.loadtxt('./Hbonds/bptf_ncptail2h33.dat', usecols=(1),unpack=True,comments=('#'))
y4h3_1 = np.loadtxt('./Hbonds/bptf_ncptail1h34.dat', usecols = (1), unpack = True, comments=('#'))
y4h3_2 = np.loadtxt('./Hbonds/bptf_ncptail2h34.dat', usecols=(1),unpack=True,comments=('#'))
y5h3_1 = np.loadtxt('./Hbonds/bptf_ncptail1h35.dat', usecols = (1), unpack = True, comments=('#'))
y5h3_2 = np.loadtxt('./Hbonds/bptf_ncptail2h35.dat', usecols=(1),unpack=True,comments=('#'))
EH3_1 = np.concatenate((y1h3_1-ydna1, y2h3_1-ydna2, y3h3_1-ydna3, y4h3_1-ydna4, y5h3_1-ydna5))
EH3_2 = np.concatenate((y1h3_2-ydna1, y2h3_2-ydna2, y3h3_2-ydna3, y4h3_2-ydna4, y5h3_2-ydna5))

#H4

y1h4_1 = np.loadtxt('./Hbonds/bptf_ncph4_tail11.dat', usecols = (1), unpack = True, comments=('#'))
y1h4_2 = np.loadtxt('./Hbonds/bptf_ncph4_tail21.dat', usecols=(1),unpack=True,comments=('#'))
y2h4_1 = np.loadtxt('./Hbonds/bptf_ncph4_tail12.dat', usecols = (1), unpack = True, comments=('#'))
y2h4_2 = np.loadtxt('./Hbonds/bptf_ncph4_tail22.dat', usecols=(1),unpack=True,comments=('#'))
y3h4_1 = np.loadtxt('./Hbonds/bptf_ncph4_tail13.dat', usecols = (1), unpack = True, comments=('#'))
y3h4_2 = np.loadtxt('./Hbonds/bptf_ncph4_tail23.dat', usecols=(1),unpack=True,comments=('#'))
y4h4_1 = np.loadtxt('./Hbonds/bptf_ncph4_tail14.dat', usecols = (1), unpack = True, comments=('#'))
y4h4_2 = np.loadtxt('./Hbonds/bptf_ncph4_tail24.dat', usecols=(1),unpack=True,comments=('#'))
y5h4_1 = np.loadtxt('./Hbonds/bptf_ncph4_tail15.dat', usecols = (1), unpack = True, comments=('#'))
y5h4_2 = np.loadtxt('./Hbonds/bptf_ncph4_tail25.dat', usecols=(1),unpack=True,comments=('#'))
EH4_1 = np.concatenate((y1h4_1-ydna1, y2h4_1-ydna2, y3h4_1-ydna3, y4h4_1-ydna4, y5h4_1-ydna5))
EH4_2 = np.concatenate((y1h4_2-ydna1, y2h4_2-ydna2, y3h4_2-ydna3, y4h4_2-ydna4, y5h4_2-ydna5))

#H2a

y1h2a_1 = np.loadtxt('./Hbonds/bptf_ncph2a1.dat', usecols = (1), unpack = True, comments=('#'))
y1h2a_2 = np.loadtxt('./Hbonds/bptf_ncph2a_11.dat', usecols=(1),unpack=True,comments=('#'))
y2h2a_1 = np.loadtxt('./Hbonds/bptf_ncph2a2.dat', usecols = (1), unpack = True, comments=('#'))
y2h2a_2 = np.loadtxt('./Hbonds/bptf_ncph2a_12.dat', usecols=(1),unpack=True,comments=('#'))
y3h2a_1 = np.loadtxt('./Hbonds/bptf_ncph2a3.dat', usecols = (1), unpack = True, comments=('#'))
y3h2a_2 = np.loadtxt('./Hbonds/bptf_ncph2a_13.dat', usecols=(1),unpack=True,comments=('#'))
y4h2a_1 = np.loadtxt('./Hbonds/bptf_ncph2a4.dat', usecols = (1), unpack = True, comments=('#'))
y4h2a_2 = np.loadtxt('./Hbonds/bptf_ncph2a_14.dat', usecols=(1),unpack=True,comments=('#'))
y5h2a_1 = np.loadtxt('./Hbonds/bptf_ncph2a5.dat', usecols = (1), unpack = True, comments=('#'))
y5h2a_2 = np.loadtxt('./Hbonds/bptf_ncph2a_15.dat', usecols=(1),unpack=True,comments=('#'))
EH2a_1 = np.concatenate((y1h2a_1-ydna1, y2h2a_1-ydna2, y3h2a_1-ydna3, y4h2a_1-ydna4, y5h2a_1-ydna5))
EH2a_2 = np.concatenate((y1h2a_2-ydna1, y2h2a_2-ydna2, y3h2a_2-ydna3, y4h2a_2-ydna4, y5h2a_2-ydna5))

#H2b

y1h2b_1 = np.loadtxt('./Hbonds/bptf_ncph2b_11.dat', usecols = (1), unpack = True, comments=('#'))
y1h2b_2 = np.loadtxt('./Hbonds/bptf_ncph2b1.dat', usecols=(1),unpack=True,comments=('#'))
y2h2b_1 = np.loadtxt('./Hbonds/bptf_ncph2b_12.dat', usecols = (1), unpack = True, comments=('#'))
y2h2b_2 = np.loadtxt('./Hbonds/bptf_ncph2b2.dat', usecols=(1),unpack=True,comments=('#'))
y3h2b_1 = np.loadtxt('./Hbonds/bptf_ncph2b_13.dat', usecols = (1), unpack = True, comments=('#'))
y3h2b_2 = np.loadtxt('./Hbonds/bptf_ncph2b3.dat', usecols=(1),unpack=True,comments=('#'))
y4h2b_1 = np.loadtxt('./Hbonds/bptf_ncph2b_14.dat', usecols = (1), unpack = True, comments=('#'))
y4h2b_2 = np.loadtxt('./Hbonds/bptf_ncph2b4.dat', usecols=(1),unpack=True,comments=('#'))
y5h2b_1 = np.loadtxt('./Hbonds/bptf_ncph2b_15.dat', usecols = (1), unpack = True, comments=('#'))
y5h2b_2 = np.loadtxt('./Hbonds/bptf_ncph2b5.dat', usecols=(1),unpack=True,comments=('#'))
EH2b_1 = np.concatenate((y1h2b_1-ydna1, y2h2b_1-ydna2, y3h2b_1-ydna3, y4h2b_1-ydna4, y5h2b_1-ydna5))
EH2b_2 = np.concatenate((y1h2b_2-ydna1, y2h2b_2-ydna2, y3h2b_2-ydna3, y4h2b_2-ydna4, y5h2b_2-ydna5))

# %%
# EnoB

x, yh3dna1 = np.loadtxt('./Hbonds/phd_ncpdnah3bond1series.dat', usecols = (0,1), unpack = True, comments=('#'))
ydna1 = np.loadtxt('./Hbonds/phd_ncpdnaseries1.dat', usecols = (1), unpack = True, comments=('#'))
y1h3 = np.loadtxt('./Hbonds/phd_ncph3bond1series.dat', usecols=(1),unpack=True,comments=('#'))

yh3dna2 = np.loadtxt('./Hbonds/phd_ncpdnah3bond2series.dat', usecols = (1), unpack = True, comments=('#'))
ydna2 = np.loadtxt('./Hbonds/phd_ncpdnaseries2.dat', usecols = (1), unpack = True, comments=('#'))
y2h3 = np.loadtxt('./Hbonds/phd_ncph3bond2series.dat', usecols=(1),unpack=True,comments=('#'))

yh3dna3 = np.loadtxt('./Hbonds/phd_ncpdnah3bond3series.dat', usecols = (1), unpack = True, comments=('#'))
ydna3 = np.loadtxt('./Hbonds/phd_ncpdnaseries3.dat', usecols = (1), unpack = True, comments=('#'))
y3h3 = np.loadtxt('./Hbonds/phd_ncph3bond3series.dat', usecols=(1),unpack=True,comments=('#'))

yh3dna4 = np.loadtxt('./Hbonds/phd_ncpdnah3bond4series.dat', usecols = (1), unpack = True, comments=('#'))
ydna4 = np.loadtxt('./Hbonds/phd_ncpdnaseries4.dat', usecols = (1), unpack = True, comments=('#'))
y4h3 = np.loadtxt('./Hbonds/phd_ncph3bond4series.dat', usecols=(1),unpack=True,comments=('#'))

yh3dna5 = np.loadtxt('./Hbonds/phd_ncpdnah3bond5series.dat', usecols = (1), unpack = True, comments=('#'))
ydna5 = np.loadtxt('./Hbonds/phd_ncpdnaseries5.dat', usecols = (1), unpack = True, comments=('#'))
y5h3 = np.loadtxt('./Hbonds/phd_ncph3bond5series.dat', usecols=(1),unpack=True,comments=('#'))

y1 = yh3dna1 - ydna1 - y1h3
y2 = yh3dna2 - ydna2 - y2h3
y3 = yh3dna3 - ydna3 - y3h3
y4 = yh3dna4 - ydna4 - y4h3
y5 = yh3dna5 - ydna5 - y5h3
EnoBH3 = np.concatenate((y1,y2,y3,y4,y5))


ah4_1 = np.loadtxt('./Hbonds/phd_ncpdnah4bond1series.dat', usecols = (1), unpack = True, comments=('#'))
a1h4 = np.loadtxt('./Hbonds/phd_ncph4bond1series.dat', usecols=(1),unpack=True,comments=('#'))
ah4_2 = np.loadtxt('./Hbonds/phd_ncpdnah4bond2series.dat', usecols = (1), unpack = True, comments=('#'))
a2h4 = np.loadtxt('./Hbonds/phd_ncph4bond2series.dat', usecols=(1),unpack=True,comments=('#'))
ah4_3 = np.loadtxt('./Hbonds/phd_ncpdnah4bond3series.dat', usecols = (1), unpack = True, comments=('#'))
a3h4 = np.loadtxt('./Hbonds/phd_ncph4bond3series.dat', usecols=(1),unpack=True,comments=('#'))
ah4_4 = np.loadtxt('./Hbonds/phd_ncpdnah4bond4series.dat', usecols = (1), unpack = True, comments=('#'))
a4h4 = np.loadtxt('./Hbonds/phd_ncph4bond4series.dat', usecols=(1),unpack=True,comments=('#'))
ah4_5 = np.loadtxt('./Hbonds/phd_ncpdnah4bond5series.dat', usecols = (1), unpack = True, comments=('#'))
a5h4 = np.loadtxt('./Hbonds/phd_ncph4bond5series.dat', usecols=(1),unpack=True,comments=('#'))

a1 = ah4_1 - ydna1 - a1h4
a2 = ah4_2 - ydna2 - a2h4
a3 = ah4_3 - ydna3 - a3h4
a4 = ah4_4 - ydna4 - a4h4
a5 = ah4_5 - ydna5 - a5h4
EnoBH4 = np.concatenate((a1,a2,a3,a4,a5))

bh2a_1 = np.loadtxt('./Hbonds/phd_ncpdnah2abond1series.dat', usecols = (1), unpack = True, comments=('#'))
b1h2a = np.loadtxt('./Hbonds/phd_ncph2abond1series.dat', usecols=(1),unpack=True,comments=('#'))
bh2a_2 = np.loadtxt('./Hbonds/phd_ncpdnah2abond2series.dat', usecols = (1), unpack = True, comments=('#'))
b2h2a = np.loadtxt('./Hbonds/phd_ncph2abond2series.dat', usecols=(1),unpack=True,comments=('#'))
bh2a_3 = np.loadtxt('./Hbonds/phd_ncpdnah2abond3series.dat', usecols = (1), unpack = True, comments=('#'))
b3h2a = np.loadtxt('./Hbonds/phd_ncph2abond3series.dat', usecols=(1),unpack=True,comments=('#'))
bh2a_4 = np.loadtxt('./Hbonds/phd_ncpdnah2abond4series.dat', usecols = (1), unpack = True, comments=('#'))
b4h2a = np.loadtxt('./Hbonds/phd_ncph2abond4series.dat', usecols=(1),unpack=True,comments=('#'))
bh2a_5 = np.loadtxt('./Hbonds/phd_ncpdnah2abond5series.dat', usecols = (1), unpack = True, comments=('#'))
b5h2a = np.loadtxt('./Hbonds/phd_ncph2abond5series.dat', usecols=(1),unpack=True,comments=('#'))

b1 = bh2a_1 - ydna1 - b1h2a
b2 = bh2a_2 - ydna2 - b2h2a
b3 = bh2a_3 - ydna3 - b3h2a
b4 = bh2a_4 - ydna4 - b4h2a
b5 = bh2a_5 - ydna5 - b5h2a
EnoBH2a = np.concatenate((b1,b2,b3,b4,b5))

ch2b_1 = np.loadtxt('./Hbonds/phd_ncpdnah2bbond1series.dat', usecols = (1), unpack = True, comments=('#'))
c1h2b = np.loadtxt('./Hbonds/phd_ncph2bbond1series.dat', usecols=(1),unpack=True,comments=('#'))
ch2b_2 = np.loadtxt('./Hbonds/phd_ncpdnah2bbond2series.dat', usecols = (1), unpack = True, comments=('#'))
c2h2b = np.loadtxt('./Hbonds/phd_ncph2bbond2series.dat', usecols=(1),unpack=True,comments=('#'))
ch2b_3 = np.loadtxt('./Hbonds/phd_ncpdnah2bbond3series.dat', usecols = (1), unpack = True, comments=('#'))
c3h2b = np.loadtxt('./Hbonds/phd_ncph2bbond3series.dat', usecols=(1),unpack=True,comments=('#'))
ch2b_4 = np.loadtxt('./Hbonds/phd_ncpdnah2bbond4series.dat', usecols = (1), unpack = True, comments=('#'))
c4h2b = np.loadtxt('./Hbonds/phd_ncph2bbond4series.dat', usecols=(1),unpack=True,comments=('#'))
ch2b_5 = np.loadtxt('./Hbonds/phd_ncpdnah2bbond5series.dat', usecols = (1), unpack = True, comments=('#'))
c5h2b = np.loadtxt('./Hbonds/phd_ncph2bbond5series.dat', usecols=(1),unpack=True,comments=('#'))

c1 = ch2b_1 - ydna1 - c1h2b
c2 = ch2b_2 - ydna2 - c2h2b
c3 = ch2b_3 - ydna3 - c3h2b
c4 = ch2b_4 - ydna4 - c4h2b
c5 = ch2b_5 - ydna5 - c5h2b
EnoBH2b = np.concatenate((c1,c2,c3,c4,c5))


# NucE, H3

y1h3_1 = np.loadtxt('./Hbonds/phd_ncptail1h31.dat', usecols = (1), unpack = True, comments=('#'))
y1h3_2 = np.loadtxt('./Hbonds/phd_ncptail2h31.dat', usecols=(1),unpack=True,comments=('#'))
y2h3_1 = np.loadtxt('./Hbonds/phd_ncptail1h32.dat', usecols = (1), unpack = True, comments=('#'))
y2h3_2 = np.loadtxt('./Hbonds/phd_ncptail2h32.dat', usecols=(1),unpack=True,comments=('#'))
y3h3_1 = np.loadtxt('./Hbonds/phd_ncptail1h33.dat', usecols = (1), unpack = True, comments=('#'))
y3h3_2 = np.loadtxt('./Hbonds/phd_ncptail2h33.dat', usecols=(1),unpack=True,comments=('#'))
y4h3_1 = np.loadtxt('./Hbonds/phd_ncptail1h34.dat', usecols = (1), unpack = True, comments=('#'))
y4h3_2 = np.loadtxt('./Hbonds/phd_ncptail2h34.dat', usecols=(1),unpack=True,comments=('#'))
y5h3_1 = np.loadtxt('./Hbonds/phd_ncptail1h35.dat', usecols = (1), unpack = True, comments=('#'))
y5h3_2 = np.loadtxt('./Hbonds/phd_ncptail2h35.dat', usecols=(1),unpack=True,comments=('#'))
EnoBH3_1 = np.concatenate((y1h3_1-ydna1, y2h3_1-ydna2, y3h3_1-ydna3, y4h3_1-ydna4, y5h3_1-ydna5))
EnoBH3_2 = np.concatenate((y1h3_2-ydna1, y2h3_2-ydna2, y3h3_2-ydna3, y4h3_2-ydna4, y5h3_2-ydna5))

#H4

y1h4_1 = np.loadtxt('./Hbonds/phd_ncph4_tail11.dat', usecols = (1), unpack = True, comments=('#'))
y1h4_2 = np.loadtxt('./Hbonds/phd_ncph4_tail21.dat', usecols=(1),unpack=True,comments=('#'))
y2h4_1 = np.loadtxt('./Hbonds/phd_ncph4_tail12.dat', usecols = (1), unpack = True, comments=('#'))
y2h4_2 = np.loadtxt('./Hbonds/phd_ncph4_tail22.dat', usecols=(1),unpack=True,comments=('#'))
y3h4_1 = np.loadtxt('./Hbonds/phd_ncph4_tail13.dat', usecols = (1), unpack = True, comments=('#'))
y3h4_2 = np.loadtxt('./Hbonds/phd_ncph4_tail23.dat', usecols=(1),unpack=True,comments=('#'))
y4h4_1 = np.loadtxt('./Hbonds/phd_ncph4_tail14.dat', usecols = (1), unpack = True, comments=('#'))
y4h4_2 = np.loadtxt('./Hbonds/phd_ncph4_tail24.dat', usecols=(1),unpack=True,comments=('#'))
y5h4_1 = np.loadtxt('./Hbonds/phd_ncph4_tail15.dat', usecols = (1), unpack = True, comments=('#'))
y5h4_2 = np.loadtxt('./Hbonds/phd_ncph4_tail25.dat', usecols=(1),unpack=True,comments=('#'))
EnoBH4_1 = np.concatenate((y1h4_1-ydna1, y2h4_1-ydna2, y3h4_1-ydna3, y4h4_1-ydna4, y5h4_1-ydna5))
EnoBH4_2 = np.concatenate((y1h4_2-ydna1, y2h4_2-ydna2, y3h4_2-ydna3, y4h4_2-ydna4, y5h4_2-ydna5))

#H2a

y1h2a_1 = np.loadtxt('./Hbonds/phd_ncph2a_11.dat', usecols = (1), unpack = True, comments=('#'))
y1h2a_2 = np.loadtxt('./Hbonds/phd_ncph2a1.dat', usecols=(1),unpack=True,comments=('#'))
y2h2a_1 = np.loadtxt('./Hbonds/phd_ncph2a_12.dat', usecols = (1), unpack = True, comments=('#'))
y2h2a_2 = np.loadtxt('./Hbonds/phd_ncph2a2.dat', usecols=(1),unpack=True,comments=('#'))
y3h2a_1 = np.loadtxt('./Hbonds/phd_ncph2a_13.dat', usecols = (1), unpack = True, comments=('#'))
y3h2a_2 = np.loadtxt('./Hbonds/phd_ncph2a3.dat', usecols=(1),unpack=True,comments=('#'))
y4h2a_1 = np.loadtxt('./Hbonds/phd_ncph2a_14.dat', usecols = (1), unpack = True, comments=('#'))
y4h2a_2 = np.loadtxt('./Hbonds/phd_ncph2a4.dat', usecols=(1),unpack=True,comments=('#'))
y5h2a_1 = np.loadtxt('./Hbonds/phd_ncph2a_15.dat', usecols = (1), unpack = True, comments=('#'))
y5h2a_2 = np.loadtxt('./Hbonds/phd_ncph2a5.dat', usecols=(1),unpack=True,comments=('#'))
EnoBH2a_1 = np.concatenate((y1h2a_1-ydna1, y2h2a_1-ydna2, y3h2a_1-ydna3, y4h2a_1-ydna4, y5h2a_1-ydna5))
EnoBH2a_2 = np.concatenate((y1h2a_2-ydna1, y2h2a_2-ydna2, y3h2a_2-ydna3, y4h2a_2-ydna4, y5h2a_2-ydna5))

#H2b

y1h2b_1 = np.loadtxt('./Hbonds/phd_ncph2b_11.dat', usecols = (1), unpack = True, comments=('#'))
y1h2b_2 = np.loadtxt('./Hbonds/phd_ncph2b1.dat', usecols=(1),unpack=True,comments=('#'))
y2h2b_1 = np.loadtxt('./Hbonds/phd_ncph2b_12.dat', usecols = (1), unpack = True, comments=('#'))
y2h2b_2 = np.loadtxt('./Hbonds/phd_ncph2b2.dat', usecols=(1),unpack=True,comments=('#'))
y3h2b_1 = np.loadtxt('./Hbonds/phd_ncph2b_13.dat', usecols = (1), unpack = True, comments=('#'))
y3h2b_2 = np.loadtxt('./Hbonds/phd_ncph2b3.dat', usecols=(1),unpack=True,comments=('#'))
y4h2b_1 = np.loadtxt('./Hbonds/phd_ncph2b_14.dat', usecols = (1), unpack = True, comments=('#'))
y4h2b_2 = np.loadtxt('./Hbonds/phd_ncph2b4.dat', usecols=(1),unpack=True,comments=('#'))
y5h2b_1 = np.loadtxt('./Hbonds/phd_ncph2b_15.dat', usecols = (1), unpack = True, comments=('#'))
y5h2b_2 = np.loadtxt('./Hbonds/phd_ncph2b5.dat', usecols=(1),unpack=True,comments=('#'))
EnoBH2b_1 = np.concatenate((y1h2b_1-ydna1, y2h2b_1-ydna2, y3h2b_1-ydna3, y4h2b_1-ydna4, y5h2b_1-ydna5))
EnoBH2b_2 = np.concatenate((y1h2b_2-ydna1, y2h2b_2-ydna2, y3h2b_2-ydna3, y4h2b_2-ydna4, y5h2b_2-ydna5))

# %%
# NucM

x, yh3dna1 = np.loadtxt('./Hbonds/nucleosomednah3bond1series.dat', usecols = (0,1), unpack = True, comments=('#'))
ydna1 = np.loadtxt('./Hbonds/nucleosomednaseries1.dat', usecols = (1), unpack = True, comments=('#'))
y1h3 = np.loadtxt('./Hbonds/nucleosomeh3bond1series.dat', usecols=(1),unpack=True,comments=('#'))

yh3dna2 = np.loadtxt('./Hbonds/nucleosomednah3bond2series.dat', usecols = (1), unpack = True, comments=('#'))
ydna2 = np.loadtxt('./Hbonds/nucleosomednaseries2.dat', usecols = (1), unpack = True, comments=('#'))
y2h3 = np.loadtxt('./Hbonds/nucleosomeh3bond2series.dat', usecols=(1),unpack=True,comments=('#'))

yh3dna3 = np.loadtxt('./Hbonds/nucleosomednah3bond3series.dat', usecols = (1), unpack = True, comments=('#'))
ydna3 = np.loadtxt('./Hbonds/nucleosomednaseries3.dat', usecols = (1), unpack = True, comments=('#'))
y3h3 = np.loadtxt('./Hbonds/nucleosomeh3bond3series.dat', usecols=(1),unpack=True,comments=('#'))

yh3dna4 = np.loadtxt('./Hbonds/nucleosomednah3bond4series.dat', usecols = (1), unpack = True, comments=('#'))
ydna4 = np.loadtxt('./Hbonds/nucleosomednaseries4.dat', usecols = (1), unpack = True, comments=('#'))
y4h3 = np.loadtxt('./Hbonds/nucleosomeh3bond4series.dat', usecols=(1),unpack=True,comments=('#'))

yh3dna5 = np.loadtxt('./Hbonds/nucleosomednah3bond5series.dat', usecols = (1), unpack = True, comments=('#'))
ydna5 = np.loadtxt('./Hbonds/nucleosomednaseries5.dat', usecols = (1), unpack = True, comments=('#'))
y5h3 = np.loadtxt('./Hbonds/nucleosomeh3bond5series.dat', usecols=(1),unpack=True,comments=('#'))

y1 = yh3dna1 - ydna1 - y1h3
y2 = yh3dna2 - ydna2 - y2h3
y3 = yh3dna3 - ydna3 - y3h3
y4 = yh3dna4 - ydna4 - y4h3
y5 = yh3dna5 - ydna5 - y5h3
MH3 = np.concatenate((y1,y2,y3,y4,y5))


ah4_1 = np.loadtxt('./Hbonds/nucleosomednah4bond1series.dat', usecols = (1), unpack = True, comments=('#'))
a1h4 = np.loadtxt('./Hbonds/nucleosomeh4bond1series.dat', usecols=(1),unpack=True,comments=('#'))
ah4_2 = np.loadtxt('./Hbonds/nucleosomednah4bond2series.dat', usecols = (1), unpack = True, comments=('#'))
a2h4 = np.loadtxt('./Hbonds/nucleosomeh4bond2series.dat', usecols=(1),unpack=True,comments=('#'))
ah4_3 = np.loadtxt('./Hbonds/nucleosomednah4bond3series.dat', usecols = (1), unpack = True, comments=('#'))
a3h4 = np.loadtxt('./Hbonds/nucleosomeh4bond3series.dat', usecols=(1),unpack=True,comments=('#'))
ah4_4 = np.loadtxt('./Hbonds/nucleosomednah4bond4series.dat', usecols = (1), unpack = True, comments=('#'))
a4h4 = np.loadtxt('./Hbonds/nucleosomeh4bond4series.dat', usecols=(1),unpack=True,comments=('#'))
ah4_5 = np.loadtxt('./Hbonds/nucleosomednah4bond5series.dat', usecols = (1), unpack = True, comments=('#'))
a5h4 = np.loadtxt('./Hbonds/nucleosomeh4bond5series.dat', usecols=(1),unpack=True,comments=('#'))

a1 = ah4_1 - ydna1 - a1h4
a2 = ah4_2 - ydna2 - a2h4
a3 = ah4_3 - ydna3 - a3h4
a4 = ah4_4 - ydna4 - a4h4
a5 = ah4_5 - ydna5 - a5h4
MH4 = np.concatenate((a1,a2,a3,a4,a5))

bh2a_1 = np.loadtxt('./Hbonds/nucleosomednah2abond1series.dat', usecols = (1), unpack = True, comments=('#'))
b1h2a = np.loadtxt('./Hbonds/nucleosomeh2abond1series.dat', usecols=(1),unpack=True,comments=('#'))
bh2a_2 = np.loadtxt('./Hbonds/nucleosomednah2abond2series.dat', usecols = (1), unpack = True, comments=('#'))
b2h2a = np.loadtxt('./Hbonds/nucleosomeh2abond2series.dat', usecols=(1),unpack=True,comments=('#'))
bh2a_3 = np.loadtxt('./Hbonds/nucleosomednah2abond3series.dat', usecols = (1), unpack = True, comments=('#'))
b3h2a = np.loadtxt('./Hbonds/nucleosomeh2abond3series.dat', usecols=(1),unpack=True,comments=('#'))
bh2a_4 = np.loadtxt('./Hbonds/nucleosomednah2abond4series.dat', usecols = (1), unpack = True, comments=('#'))
b4h2a = np.loadtxt('./Hbonds/nucleosomeh2abond4series.dat', usecols=(1),unpack=True,comments=('#'))
bh2a_5 = np.loadtxt('./Hbonds/nucleosomednah2abond5series.dat', usecols = (1), unpack = True, comments=('#'))
b5h2a = np.loadtxt('./Hbonds/nucleosomeh2abond5series.dat', usecols=(1),unpack=True,comments=('#'))

b1 = bh2a_1 - ydna1 - b1h2a
b2 = bh2a_2 - ydna2 - b2h2a
b3 = bh2a_3 - ydna3 - b3h2a
b4 = bh2a_4 - ydna4 - b4h2a
b5 = bh2a_5 - ydna5 - b5h2a
MH2a = np.concatenate((b1,b2,b3,b4,b5))

ch2b_1 = np.loadtxt('./Hbonds/nucleosomednah2bbond1series.dat', usecols = (1), unpack = True, comments=('#'))
c1h2b = np.loadtxt('./Hbonds/nucleosomeh2bbond1series.dat', usecols=(1),unpack=True,comments=('#'))
ch2b_2 = np.loadtxt('./Hbonds/nucleosomednah2bbond2series.dat', usecols = (1), unpack = True, comments=('#'))
c2h2b = np.loadtxt('./Hbonds/nucleosomeh2bbond2series.dat', usecols=(1),unpack=True,comments=('#'))
ch2b_3 = np.loadtxt('./Hbonds/nucleosomednah2bbond3series.dat', usecols = (1), unpack = True, comments=('#'))
c3h2b = np.loadtxt('./Hbonds/nucleosomeh2bbond3series.dat', usecols=(1),unpack=True,comments=('#'))
ch2b_4 = np.loadtxt('./Hbonds/nucleosomednah2bbond4series.dat', usecols = (1), unpack = True, comments=('#'))
c4h2b = np.loadtxt('./Hbonds/nucleosomeh2bbond4series.dat', usecols=(1),unpack=True,comments=('#'))
ch2b_5 = np.loadtxt('./Hbonds/nucleosomednah2bbond5series.dat', usecols = (1), unpack = True, comments=('#'))
c5h2b = np.loadtxt('./Hbonds/nucleosomeh2bbond5series.dat', usecols=(1),unpack=True,comments=('#'))

c1 = ch2b_1 - ydna1 - c1h2b
c2 = ch2b_2 - ydna2 - c2h2b
c3 = ch2b_3 - ydna3 - c3h2b
c4 = ch2b_4 - ydna4 - c4h2b
c5 = ch2b_5 - ydna5 - c5h2b
MH2b = np.concatenate((c1,c2,c3,c4,c5))

# NucM, H3

y1h3_1 = np.loadtxt('./Hbonds/nucleosometail1h31.dat', usecols = (1), unpack = True, comments=('#'))
y1h3_2 = np.loadtxt('./Hbonds/nucleosometail2h31.dat', usecols=(1),unpack=True,comments=('#'))
y2h3_1 = np.loadtxt('./Hbonds/nucleosometail1h32.dat', usecols = (1), unpack = True, comments=('#'))
y2h3_2 = np.loadtxt('./Hbonds/nucleosometail2h32.dat', usecols=(1),unpack=True,comments=('#'))
y3h3_1 = np.loadtxt('./Hbonds/nucleosometail1h33.dat', usecols = (1), unpack = True, comments=('#'))
y3h3_2 = np.loadtxt('./Hbonds/nucleosometail2h33.dat', usecols=(1),unpack=True,comments=('#'))
y4h3_1 = np.loadtxt('./Hbonds/nucleosometail1h34.dat', usecols = (1), unpack = True, comments=('#'))
y4h3_2 = np.loadtxt('./Hbonds/nucleosometail2h34.dat', usecols=(1),unpack=True,comments=('#'))
y5h3_1 = np.loadtxt('./Hbonds/nucleosometail1h35.dat', usecols = (1), unpack = True, comments=('#'))
y5h3_2 = np.loadtxt('./Hbonds/nucleosometail2h35.dat', usecols=(1),unpack=True,comments=('#'))
MH3_1 = np.concatenate((y1h3_1-ydna1, y2h3_1-ydna2, y3h3_1-ydna3, y4h3_1-ydna4, y5h3_1-ydna5))
MH3_2 = np.concatenate((y1h3_2-ydna1, y2h3_2-ydna2, y3h3_2-ydna3, y4h3_2-ydna4, y5h3_2-ydna5))

#H4

y1h4_1 = np.loadtxt('./Hbonds/nucleosomeh4_tail11.dat', usecols = (1), unpack = True, comments=('#'))
y1h4_2 = np.loadtxt('./Hbonds/nucleosomeh4_tail21.dat', usecols=(1),unpack=True,comments=('#'))
y2h4_1 = np.loadtxt('./Hbonds/nucleosomeh4_tail12.dat', usecols = (1), unpack = True, comments=('#'))
y2h4_2 = np.loadtxt('./Hbonds/nucleosomeh4_tail22.dat', usecols=(1),unpack=True,comments=('#'))
y3h4_1 = np.loadtxt('./Hbonds/nucleosomeh4_tail13.dat', usecols = (1), unpack = True, comments=('#'))
y3h4_2 = np.loadtxt('./Hbonds/nucleosomeh4_tail23.dat', usecols=(1),unpack=True,comments=('#'))
y4h4_1 = np.loadtxt('./Hbonds/nucleosomeh4_tail14.dat', usecols = (1), unpack = True, comments=('#'))
y4h4_2 = np.loadtxt('./Hbonds/nucleosomeh4_tail24.dat', usecols=(1),unpack=True,comments=('#'))
y5h4_1 = np.loadtxt('./Hbonds/nucleosomeh4_tail15.dat', usecols = (1), unpack = True, comments=('#'))
y5h4_2 = np.loadtxt('./Hbonds/nucleosomeh4_tail25.dat', usecols=(1),unpack=True,comments=('#'))
MH4_1 = np.concatenate((y1h4_1-ydna1, y2h4_1-ydna2, y3h4_1-ydna3, y4h4_1-ydna4, y5h4_1-ydna5))
MH4_2 = np.concatenate((y1h4_2-ydna1, y2h4_2-ydna2, y3h4_2-ydna3, y4h4_2-ydna4, y5h4_2-ydna5))

#H2a

y1h2a_1 = np.loadtxt('./Hbonds/nucleosomeh2a_11.dat', usecols = (1), unpack = True, comments=('#'))
y1h2a_2 = np.loadtxt('./Hbonds/nucleosomeh2a1.dat', usecols=(1),unpack=True,comments=('#'))
y2h2a_1 = np.loadtxt('./Hbonds/nucleosomeh2a_12.dat', usecols = (1), unpack = True, comments=('#'))
y2h2a_2 = np.loadtxt('./Hbonds/nucleosomeh2a2.dat', usecols=(1),unpack=True,comments=('#'))
y3h2a_1 = np.loadtxt('./Hbonds/nucleosomeh2a_13.dat', usecols = (1), unpack = True, comments=('#'))
y3h2a_2 = np.loadtxt('./Hbonds/nucleosomeh2a3.dat', usecols=(1),unpack=True,comments=('#'))
y4h2a_1 = np.loadtxt('./Hbonds/nucleosomeh2a_14.dat', usecols = (1), unpack = True, comments=('#'))
y4h2a_2 = np.loadtxt('./Hbonds/nucleosomeh2a4.dat', usecols=(1),unpack=True,comments=('#'))
y5h2a_1 = np.loadtxt('./Hbonds/nucleosomeh2a_15.dat', usecols = (1), unpack = True, comments=('#'))
y5h2a_2 = np.loadtxt('./Hbonds/nucleosomeh2a5.dat', usecols=(1),unpack=True,comments=('#'))
MH2a_1 = np.concatenate((y1h2a_1-ydna1, y2h2a_1-ydna2, y3h2a_1-ydna3, y4h2a_1-ydna4, y5h2a_1-ydna5))
MH2a_2 = np.concatenate((y1h2a_2-ydna1, y2h2a_2-ydna2, y3h2a_2-ydna3, y4h2a_2-ydna4, y5h2a_2-ydna5))

#H2b

y1h2b_1 = np.loadtxt('./Hbonds/nucleosomeh2b_11.dat', usecols = (1), unpack = True, comments=('#'))
y1h2b_2 = np.loadtxt('./Hbonds/nucleosomeh2b1.dat', usecols=(1),unpack=True,comments=('#'))
y2h2b_1 = np.loadtxt('./Hbonds/nucleosomeh2b_12.dat', usecols = (1), unpack = True, comments=('#'))
y2h2b_2 = np.loadtxt('./Hbonds/nucleosomeh2b2.dat', usecols=(1),unpack=True,comments=('#'))
y3h2b_1 = np.loadtxt('./Hbonds/nucleosomeh2b_13.dat', usecols = (1), unpack = True, comments=('#'))
y3h2b_2 = np.loadtxt('./Hbonds/nucleosomeh2b3.dat', usecols=(1),unpack=True,comments=('#'))
y4h2b_1 = np.loadtxt('./Hbonds/nucleosomeh2b_14.dat', usecols = (1), unpack = True, comments=('#'))
y4h2b_2 = np.loadtxt('./Hbonds/nucleosomeh2b4.dat', usecols=(1),unpack=True,comments=('#'))
y5h2b_1 = np.loadtxt('./Hbonds/nucleosomeh2b_15.dat', usecols = (1), unpack = True, comments=('#'))
y5h2b_2 = np.loadtxt('./Hbonds/nucleosomeh2b5.dat', usecols=(1),unpack=True,comments=('#'))
MH2b_1 = np.concatenate((y1h2b_1-ydna1, y2h2b_1-ydna2, y3h2b_1-ydna3, y4h2b_1-ydna4, y5h2b_1-ydna5))
MH2b_2 = np.concatenate((y1h2b_2-ydna1, y2h2b_2-ydna2, y3h2b_2-ydna3, y4h2b_2-ydna4, y5h2b_2-ydna5))

# %%
import matplotlib.pyplot as plt
import numpy as np

font = {'family': 'sans-serif',
        'color':  'black',
        'size': 12,
        }
        
label = ['NCP', 'PHD + NCP', 'BPTF + NCP']
h3 = np.array([stat.mean(MH3), stat.mean(EnoBH3), stat.mean(EH3)])
h4=np.array([stat.mean(MH4), stat.mean(EnoBH4), stat.mean(EH4)])
h2a = np.array([stat.mean(MH2a), stat.mean(EnoBH2a), stat.mean(EH2a)])
h2b = np.array([stat.mean(MH2b), stat.mean(EnoBH2b), stat.mean(EH2b)])


h3_sd = np.array([stat.stdev(MH3)/2.2, stat.stdev(EnoBH3)/2.2, stat.stdev(EH3)/2.2])
h4_sd = np.array([stat.stdev(MH4)/2.2, stat.stdev(EnoBH4)/2.2, stat.stdev(EH4)/2.2])
h2a_sd = np.array([stat.stdev(MH2a)/2.2, stat.stdev(EnoBH2a)/2.2, stat.stdev(EH2a)/2.2])
h2b_sd = np.array([stat.stdev(MH2b)/2.2, stat.stdev(EnoBH2b)/2.2, stat.stdev(EH2b)/2.2])

width = 0.35       # the width of the bars: can also be len(x) sequence


#plt.figure(figsize=(8.5,6.47))
plt.figure(figsize=(5,3.5))

plt.bar(label, h4, width, yerr=h4_sd, capsize = 3, bottom=h2a+h2b+h3, label='H4', color='green')
plt.bar(label, h3, width, yerr=h3_sd, capsize = 3, bottom=h2a+h2b, label='H3', color='blue')
plt.bar(label, h2b, width, yerr=h2b_sd, capsize = 3, bottom=h2a, label='H2B', color='red')
plt.bar(label, h2a, width, yerr=h2a_sd, capsize = 3, label="H2A", color='yellow')
plt.ylabel('Hydrogen Bonds', fontdict=font)
plt.title('Histone Hydrogen Bonds with DNA', fontdict=font)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.legend(bbox_to_anchor=(1.0, 0.75), fontsize=10)
plt.tight_layout()

plt.savefig('Hbonds_dif.pdf')
