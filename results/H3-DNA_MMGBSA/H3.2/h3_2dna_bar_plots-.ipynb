# %%
import pandas as pd
import re
from math import sqrt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

filename1 = "./BPTF_NCP/E1gbsa.txt"
filename2 = "./BPTF_NCP/E2gbsa.txt"
filename3 = "./BPTF_NCP/E3gbsa.txt"
filename4 = "./BPTF_NCP/E4gbsa.txt"
filename5 = "./BPTF_NCP/E5gbsa.txt"

f1 = "./PHD_NCP/EnoB1gbsa.txt"
f2 = "./PHD_NCP/EnoB2gbsa.txt"
f3 = "./PHD_NCP/EnoB3gbsa.txt"
f4 = "./PHD_NCP/EnoB4gbsa.txt"
f5 = "./PHD_NCP/EnoB5gbsa.txt"

m1 = "./NCP/M1gbsa.txt"
m2 = "./NCP/M2gbsa.txt"
m3 = "./NCP/M3gbsa.txt"
m4 = "./NCP/M4gbsa.txt"
m5 = "./NCP/M5gbsa.txt"
# Pattern: match any line that has 6 columns with "value +/- error"
value_pattern = re.compile(r"([-\d.Ee]+)\s+\+/-\s+([-\d.Ee]+)")

data1 = []
data2 = []
data3 = []
data4 = []
data5 = []

d1 = []
d2 = []
d3 = []
d4 = []
d5 = []

dm1 = []
dm2 = []
dm3 = []
dm4 = []
dm5 = []
failures = []

with open(filename1) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data1.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename2) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data2.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename3) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data3.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename4) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data4.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename5) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data5.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f1) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d1.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f2) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d2.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f3) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d3.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f4) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d4.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f5) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d5.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(m1) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    dm1.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(m2) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    dm2.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(m3) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    dm3.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(m4) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    dm4.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(m5) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    dm5.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

# Define column headers
columns = [
    "Residue",
    "Internal", "Internal_err",
    "VDW", "VDW_err",
    "Electrostatic", "Electrostatic_err",
    "Polar", "Polar_err",
    "NonPolar", "NonPolar_err",
    "Total", "Total_err"
]

df1 = pd.DataFrame(data1, columns=columns)
df2 = pd.DataFrame(data2, columns=columns)
df3 = pd.DataFrame(data3, columns=columns)
df4 = pd.DataFrame(data4, columns=columns)
df5 = pd.DataFrame(data5, columns=columns)

df6 = pd.DataFrame(d1, columns=columns)
df7 = pd.DataFrame(d2, columns=columns)
df8 = pd.DataFrame(d3, columns=columns)
df9 = pd.DataFrame(d4, columns=columns)
df10 = pd.DataFrame(d5, columns=columns)

df11 = pd.DataFrame(dm1, columns=columns)
df12 = pd.DataFrame(dm2, columns=columns)
df13 = pd.DataFrame(dm3, columns=columns)
df14 = pd.DataFrame(dm4, columns=columns)
df15 = pd.DataFrame(dm5, columns=columns)
# ✅ Summary
print(f"✅ Parsed {len(df1)} residues.")
print(df1.head())

# Optional debug
if failures:
    print(f"\n⚠️ Skipped {len(failures)} lines. First 5:")
    for f in failures[:5]:
        print(f)
# Out:
# ✅ Parsed 330 residues.
#   Residue  Internal  Internal_err    VDW  VDW_err  Electrostatic  \
# 0    DA51       0.0           0.0 -0.041    0.079        -21.011
# 1     DT2       0.0           0.0 -0.154    0.239        -73.435
# 2     DC3       0.0           0.0 -0.877    0.899       -105.778
# 3     DA4       0.0           0.0 -2.182    1.259       -135.501
# 4     DA5       0.0           0.0 -3.282    1.099       -145.935
#
#    Electrostatic_err    Polar  Polar_err  NonPolar  NonPolar_err  Total  \
# 0              1.308   20.946      1.276    -0.003         0.019 -0.109
# 1              3.920   73.437      3.901    -0.013         0.034 -0.164
# 2              7.484  103.666      6.774    -0.160         0.153 -3.149
# 3             12.422  134.498     11.267    -0.504         0.171 -3.688
# 4              9.375  144.784      8.434    -0.582         0.108 -5.015
#
#    Total_err
# 0      0.164
# 1      0.187
# 2      2.707
# 3      1.584
# 4      1.620
#
# ⚠️ Skipped 45 lines. First 5:
# Wrong # of value/error pairs: | Run on Tue Jun  3 21:52:16 2025
# Wrong # of value/error pairs: || GB non-polar solvation energies calculated with gbsa=2
# Wrong # of value/error pairs: Residue |  Location |       Internal      |    van der Waals    |    Electrostatic    |   Polar Solvation   |    Non-Polar Solv.  |       TOTAL
# Wrong # of value/error pairs: | Run on Tue Jun  3 21:28:54 2025
# Wrong # of value/error pairs: || GB non-polar solvation energies calculated with gbsa=2

# %%
df5
# Out:
#     Residue  Internal  Internal_err    VDW  VDW_err  Electrostatic  \
# 0      DA51       0.0           0.0 -0.037    0.013        -24.617
# 1       DT2       0.0           0.0 -0.250    0.070        -86.065
# 2       DC3       0.0           0.0 -3.621    0.962       -120.751
# 3       DA4       0.0           0.0 -6.289    1.041       -153.983
# 4       DA5       0.0           0.0 -4.225    1.004       -167.759
# ..      ...       ...           ...    ...      ...            ...
# 325  THR326       0.0           0.0 -0.106    0.062         -2.460
# 326  GLY327       0.0           0.0 -0.038    0.018         -2.296
# 327  GLY328       0.0           0.0 -0.036    0.016          7.150
# 328  VAL329       0.0           0.0 -0.138    0.162          3.545
# 329  LYS330       0.0           0.0 -1.205    1.229       -943.561
#
#      Electrostatic_err    Polar  Polar_err  NonPolar  NonPolar_err  Total  \
# 0                1.176   24.599      1.166    -0.000         0.002 -0.055
# 1                3.956   86.037      3.943    -0.001         0.003 -0.279
# 2                6.867  119.888      6.472    -0.455         0.085 -4.940
# 3               10.694  152.015      9.677    -0.909         0.097 -9.167
# 4               10.903  166.452      9.624    -0.789         0.098 -6.321
# ..                 ...      ...        ...       ...           ...    ...
# 325              7.908    2.569      7.892    -0.000         0.003  0.002
# 326              8.789    2.368      8.749     0.000         0.000  0.034
# 327              5.651   -7.020      5.648     0.000         0.000  0.095
# 328              5.836   -3.369      5.813    -0.011         0.037  0.027
# 329             31.934  947.048     35.435    -0.305         0.291  1.976
#
#      Total_err
# 0        0.029
# 1        0.088
# 2        1.550
# 3        2.292
# 4        1.964
# ..         ...
# 325      0.104
# 326      0.058
# 327      0.042
# 328      0.086
# 329      3.345
#
# [330 rows x 13 columns]

# %%
# Ensure each df has a numeric residue ID column
for df in [df1, df2, df3, df4, df5]:
    df["ResID"] = df["Residue"].str.extract(r"(\d+)$").astype(int)

# Extract Total energy for residues 295–309 from each df
dfs = []
for i, df in enumerate([df1, df2, df3, df4, df5], start=1):
    subset = df[(df["ResID"] >= 295) & (df["ResID"] <= 330)].copy()
    subset = subset[["Residue", "Total"]].rename(columns={"Total": f"Total_{i}"})
    dfs.append(subset)

# Merge on Residue
merged = dfs[0]
for df in dfs[1:]:
    merged = pd.merge(merged, df, on="Residue")

# Calculate mean and std across the 5 Total columns
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 6)]].mean(axis=1)
merged["Total_std"] = merged[[f"Total_{i}" for i in range(1, 6)]].std(axis=1)

# After merging the Total columns:

# Also merge Total_err columns from each df
for i, df in enumerate([df1, df2, df3, df4, df5], start=1):
    subset_err = df[(df["ResID"] >= 295) & (df["ResID"] <= 330)].copy()
    subset_err = subset_err[["Residue", "Total_err"]].rename(columns={"Total_err": f"Total_err_{i}"})
    merged = pd.merge(merged, subset_err, on="Residue")

# Calculate mean of Total values (same as before)
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 6)]].mean(axis=1)

# Propagate the standard deviations of the Total_err columns
# Standard error of the mean = sqrt(sum of variances) / N
merged["Total_err_propagated"] = np.sqrt(
    np.sum(np.square(merged[[f"Total_err_{i}" for i in range(1, 6)]]), axis=1)
) / 5

# Final result with propagated error
result = merged[["Residue", "Total_mean", "Total_err_propagated"]]

print(result)
# Out:
#    Residue  Total_mean  Total_err_propagated
# 0   ALA295      4.0672              2.324153
# 1   ARG296     -1.7372              0.919828
# 2   THR297     -1.0874              0.798265
# 3   LYS298     -1.0460              0.915306
# 4   GLN299     -0.8220              0.552710
# 5   THR300     -0.2478              0.432117
# 6   ALA301     -0.7092              0.256378
# 7   ARG302     -2.1462              0.818277
# 8   LYS303      0.3834              1.366755
# 9   SER304     -0.6416              0.659666
# 10  THR305     -1.4462              0.611929
# 11  GLY306     -0.8702              0.350435
# 12  GLY307     -0.2194              0.298793
# 13  LYS308      1.7792              1.637112
# 14  ALA309     -0.3770              0.347430
# 15  PRO310     -0.7950              0.440557
# 16  ARG311     -1.4722              0.985444
# 17  LYS312      1.4766              1.733351
# 18  GLN313      0.0238              0.236639
# 19  LEU314     -0.4356              0.335369
# 20  ALA315     -0.2124              0.282274
# 21  THR316     -0.6444              0.271169
# 22  LYS317     -0.3874              1.001042
# 23  ALA318     -0.1548              0.247863
# 24  ALA319     -0.2194              0.247650
# 25  ARG320     -2.3716              0.676517
# 26  LYS321     -0.8934              0.998295
# 27  SER322     -0.2788              0.436946
# 28  ALA323     -0.1736              0.231820
# 29  PRO324     -0.4342              0.318728
# 30  ALA325     -0.1904              0.210792
# 31  THR326     -0.0310              0.164636
# 32  GLY327     -0.0562              0.160591
# 33  GLY328     -0.1234              0.186728
# 34  VAL329     -0.2202              0.319194
# 35  LYS330      2.0722              1.716450

# %%
# Ensure each df has a numeric residue ID column
for df in [df1, df2, df3, df4, df5]:
    df["ResID"] = df["Residue"].str.extract(r"(\d+)$").astype(int)

# Extract Total energy for residues 295–309 from each df
dfs = []
for i, df in enumerate([df1, df2, df3, df4, df5], start=1):
    subset = df[(df["ResID"] >= 295) & (df["ResID"] <= 330)].copy()
    subset = subset[["Residue", "Total"]].rename(columns={"Total": f"Total_{i}"})
    dfs.append(subset)

# Merge on Residue
merged = dfs[0]
for df in dfs[1:]:
    merged = pd.merge(merged, df, on="Residue")

# Calculate mean and std across the 5 Total columns
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 6)]].mean(axis=1)
merged["Total_std"] = merged[[f"Total_{i}" for i in range(1, 6)]].std(axis=1)

# After merging the Total columns:

# Also merge Total_err columns from each df
for i, df in enumerate([df1, df2, df3, df4, df5], start=1):
    subset_err = df[(df["ResID"] >= 295) & (df["ResID"] <= 330)].copy()
    subset_err = subset_err[["Residue", "Total_err"]].rename(columns={"Total_err": f"Total_err_{i}"})
    merged = pd.merge(merged, subset_err, on="Residue")

# Calculate mean of Total values (same as before)
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 6)]].mean(axis=1)

# Propagate the standard deviations of the Total_err columns
# Standard error of the mean = sqrt(sum of variances) / N
merged["Total_err_propagated"] = np.sqrt(
    np.sum(np.square(merged[[f"Total_err_{i}" for i in range(1, 6)]]), axis=1)
) / 5

# Final result with propagated error
result = merged[["Residue", "Total_mean", "Total_err_propagated"]]

print(result)
# Out:
#    Residue  Total_mean  Total_err_propagated
# 0   ALA295      4.0672              2.324153
# 1   ARG296     -1.7372              0.919828
# 2   THR297     -1.0874              0.798265
# 3   LYS298     -1.0460              0.915306
# 4   GLN299     -0.8220              0.552710
# 5   THR300     -0.2478              0.432117
# 6   ALA301     -0.7092              0.256378
# 7   ARG302     -2.1462              0.818277
# 8   LYS303      0.3834              1.366755
# 9   SER304     -0.6416              0.659666
# 10  THR305     -1.4462              0.611929
# 11  GLY306     -0.8702              0.350435
# 12  GLY307     -0.2194              0.298793
# 13  LYS308      1.7792              1.637112
# 14  ALA309     -0.3770              0.347430
# 15  PRO310     -0.7950              0.440557
# 16  ARG311     -1.4722              0.985444
# 17  LYS312      1.4766              1.733351
# 18  GLN313      0.0238              0.236639
# 19  LEU314     -0.4356              0.335369
# 20  ALA315     -0.2124              0.282274
# 21  THR316     -0.6444              0.271169
# 22  LYS317     -0.3874              1.001042
# 23  ALA318     -0.1548              0.247863
# 24  ALA319     -0.2194              0.247650
# 25  ARG320     -2.3716              0.676517
# 26  LYS321     -0.8934              0.998295
# 27  SER322     -0.2788              0.436946
# 28  ALA323     -0.1736              0.231820
# 29  PRO324     -0.4342              0.318728
# 30  ALA325     -0.1904              0.210792
# 31  THR326     -0.0310              0.164636
# 32  GLY327     -0.0562              0.160591
# 33  GLY328     -0.1234              0.186728
# 34  VAL329     -0.2202              0.319194
# 35  LYS330      2.0722              1.716450

# %%
# Ensure each df has a numeric residue ID column
for df in [df6, df7, df8, df9, df10]:
    df["ResID"] = df["Residue"].str.extract(r"(\d+)$").astype(int)

# Extract Total energy for residues 295–309 from each df
df2s = []
for i, df in enumerate([df6, df7, df8, df9, df10], start=1):
    subset = df[(df["ResID"] >= 295) & (df["ResID"] <= 330)].copy()
    subset = subset[["Residue", "Total"]].rename(columns={"Total": f"Total_{i}"})
    df2s.append(subset)

# Merge on Residue
merged = df2s[0]
for df in df2s[1:]:
    merged = pd.merge(merged, df, on="Residue")

# Calculate mean and std across the 5 Total columns
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 6)]].mean(axis=1)
merged["Total_std"] = merged[[f"Total_{i}" for i in range(1, 6)]].std(axis=1)

# After merging the Total columns:

# Also merge Total_err columns from each df
for i, df in enumerate([df6, df7, df8, df9, df10], start=1):
    subset_err = df[(df["ResID"] >= 295) & (df["ResID"] <= 330)].copy()
    subset_err = subset_err[["Residue", "Total_err"]].rename(columns={"Total_err": f"Total_err_{i}"})
    merged = pd.merge(merged, subset_err, on="Residue")

# Calculate mean of Total values (same as before)
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 6)]].mean(axis=1)

# Propagate the standard deviations of the Total_err columns
# Standard error of the mean = sqrt(sum of variances) / N
merged["Total_err_propagated"] = np.sqrt(
    np.sum(np.square(merged[[f"Total_err_{i}" for i in range(1, 6)]]), axis=1)
) / 5

# Final result with propagated error
result2 = merged[["Residue", "Total_mean", "Total_err_propagated"]]

print(result2)
# Out:
#    Residue  Total_mean  Total_err_propagated
# 0   ALA295      2.3356              1.558168
# 1   ARG296     -2.1644              0.785816
# 2   THR297     -0.6466              0.465965
# 3   LYS298     -0.7744              1.159665
# 4   GLN299      0.0382              0.283773
# 5   THR300     -0.1472              0.346364
# 6   ALA301     -0.0848              0.212121
# 7   ARG302     -1.8254              0.699085
# 8   LYS303      1.5862              1.558566
# 9   SER304     -0.5834              0.521497
# 10  THR305     -0.4176              0.398173
# 11  GLY306     -0.6852              0.343384
# 12  GLY307     -0.1402              0.258492
# 13  LYS308     -0.7470              1.000187
# 14  ALA309     -0.2526              0.256035
# 15  PRO310     -0.7472              0.254496
# 16  ARG311     -1.5392              0.799032
# 17  LYS312      1.2212              1.090139
# 18  GLN313     -0.1484              0.394141
# 19  LEU314     -0.3612              0.316615
# 20  ALA315     -0.2556              0.254660
# 21  THR316     -0.4562              0.427858
# 22  LYS317     -0.3140              1.474212
# 23  ALA318     -0.4110              0.309096
# 24  ALA319     -0.1676              0.211574
# 25  ARG320     -0.9450              0.572589
# 26  LYS321      0.2128              1.210956
# 27  SER322     -0.0672              0.311158
# 28  ALA323     -0.2002              0.163155
# 29  PRO324     -0.7262              0.464270
# 30  ALA325     -0.1864              0.215382
# 31  THR326     -0.2098              0.361693
# 32  GLY327     -0.0154              0.142767
# 33  GLY328      0.0118              0.123057
# 34  VAL329     -0.1936              0.292099
# 35  LYS330      2.8048              2.099657

# %%
# Ensure each df has a numeric residue ID column
for df in [df11, df12, df13, df14, df15]:
    df["ResID"] = df["Residue"].str.extract(r"(\d+)$").astype(int)

# Extract Total energy for residues 295–309 from each df
df2s = []
for i, df in enumerate([df11, df12, df13, df14, df15], start=1):
    subset = df[(df["ResID"] >= 295) & (df["ResID"] <= 330)].copy()
    subset = subset[["Residue", "Total"]].rename(columns={"Total": f"Total_{i}"})
    df2s.append(subset)

# Merge on Residue
merged = df2s[0]
for df in df2s[1:]:
    merged = pd.merge(merged, df, on="Residue")

# Calculate mean and std across the 5 Total columns
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 6)]].mean(axis=1)
merged["Total_std"] = merged[[f"Total_{i}" for i in range(1, 6)]].std(axis=1)

# After merging the Total columns:

# Also merge Total_err columns from each df
for i, df in enumerate([df11, df12, df13, df14, df15], start=1):
    subset_err = df[(df["ResID"] >= 295) & (df["ResID"] <= 330)].copy()
    subset_err = subset_err[["Residue", "Total_err"]].rename(columns={"Total_err": f"Total_err_{i}"})
    merged = pd.merge(merged, subset_err, on="Residue")

# Calculate mean of Total values (same as before)
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 6)]].mean(axis=1)

# Propagate the standard deviations of the Total_err columns
# Standard error of the mean = sqrt(sum of variances) / N
merged["Total_err_propagated"] = np.sqrt(
    np.sum(np.square(merged[[f"Total_err_{i}" for i in range(1, 6)]]), axis=1)
) / 5

# Final result with propagated error
result3 = merged[["Residue", "Total_mean", "Total_err_propagated"]]

print(result3)
# Out:
#    Residue  Total_mean  Total_err_propagated
# 0   ALA295      3.6172              2.076746
# 1   ARG296     -2.9174              0.861358
# 2   THR297     -0.4050              0.592048
# 3   LYS298      4.0182              1.771547
# 4   GLN299     -0.7130              0.605144
# 5   THR300     -1.3514              0.832471
# 6   ALA301     -0.2152              0.330587
# 7   ARG302     -1.2900              0.783304
# 8   LYS303      0.7142              1.548560
# 9   SER304     -0.4224              0.537468
# 10  THR305     -0.2238              0.359945
# 11  GLY306     -0.3564              0.253711
# 12  GLY307     -0.4962              0.294188
# 13  LYS308      1.3392              1.019956
# 14  ALA309     -0.0762              0.258846
# 15  PRO310     -0.4478              0.255543
# 16  ARG311     -1.7422              0.725590
# 17  LYS312      1.2706              1.495829
# 18  GLN313     -0.6216              0.483045
# 19  LEU314     -0.4806              0.361234
# 20  ALA315     -0.3256              0.307862
# 21  THR316     -0.5400              0.470247
# 22  LYS317      0.5814              1.286020
# 23  ALA318     -0.4676              0.279482
# 24  ALA319     -0.0700              0.314792
# 25  ARG320     -1.4958              0.772506
# 26  LYS321     -0.9916              0.747167
# 27  SER322     -0.9494              0.611019
# 28  ALA323     -0.3364              0.290275
# 29  PRO324     -0.4216              0.408937
# 30  ALA325     -0.3752              0.341502
# 31  THR326     -0.2806              0.360175
# 32  GLY327     -0.0934              0.173188
# 33  GLY328     -0.0348              0.135967
# 34  VAL329      0.0462              0.226509
# 35  LYS330      4.2074              2.188599

# %%
avg1 = np.array(result['Total_mean'])
avg2 = np.array(result2['Total_mean'])
avg3 = np.array(result3['Total_mean'])

std = np.array(result['Total_err_propagated'])
std2 = np.array(result2['Total_err_propagated'])
std3 = np.array(result3['Total_err_propagated'])

ste1 = std/sqrt(5)
ste2 = std2/sqrt(4)
ste3 = std3/sqrt(5)

# %%
import numpy as np
import matplotlib.pyplot as plt

width = 0.25

# Residue labels (36 total)
residues = ['A1','R2','T3','K4','Q5','T6','A7','R8','K9','S10','T11','G12','G13','K14',
            'A15','P16','R17','K18','Q19','L20','A21','T22','K23','A24','A25','R26','K27',
            'S28','A29','P30','A31','T32','G33','G34','V35','K36']

# Split into two halves
mid = len(residues) // 2
res1 = residues[:mid]    # First 18
res2 = residues[mid:]    # Last 18

# x positions
x1 = np.arange(1, mid + 1)
x2 = np.arange(mid + 1, len(residues) + 1)

# === Plotting ===
fig, axes = plt.subplots(2, 1, figsize=(6, 6), sharey=True)

# --- Top: First half ---
axes[0].bar(x1 - width, avg3[:mid], yerr=ste3[:mid], width=width, label="NCP", color='gray')
axes[0].bar(x1,         avg2[:mid], yerr=ste2[:mid], width=width, label="NCP + PHD", color='blue')
axes[0].bar(x1 + width, avg1[:mid], yerr=ste1[:mid], width=width, label="NCP + BPTF", color='red')
axes[0].set_xticks(x1)
axes[0].set_xticklabels(res1, rotation=90)
axes[0].axhline(0, color='black', linewidth=0.8)
axes[0].set_ylabel("Binding Energy (kcal/mol)")
axes[0].legend(loc='upper center')
axes[0].set_title("H3 (No PTM) Tail Binding Energy (Residues 1–18)")

# --- Bottom: Second half ---
axes[1].bar(x2 - width, avg3[mid:], yerr=ste3[mid:], width=width, color='gray')
axes[1].bar(x2,         avg2[mid:], yerr=ste2[mid:], width=width, color='blue')
axes[1].bar(x2 + width, avg1[mid:], yerr=ste1[mid:], width=width, color='red')
axes[1].set_xticks(x2)
axes[1].set_xticklabels(res2, rotation=90)
axes[1].axhline(0, color='black', linewidth=0.8)
axes[1].set_xlabel("Residue")
axes[1].set_ylabel("Binding Energy (kcal/mol)")
axes[1].set_title("H3 Tail-DNA Binding Energy (Residues 19–36)")

plt.tight_layout()
plt.savefig("h3_gbsa_byres_split.pdf")
